# %% [markdown]
# <a href="https://colab.research.google.com/github/Adriana-FLW/MBA_TCC/blob/main/00_Leitura_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ENEM 2022**

# %% [markdown]
# # Biblioteca

# %%
import pandas as pd
import zipfile

# %% [markdown]
# # Importar Dados

# %% [markdown]
# - **Localizar microdados**

# %%
with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2022.zip') as z:
  print(*z.namelist(),sep='\n')
# Out:
# DICION╡RIO/
# DICION╡RIO/Dicionário_Microdados_Enem_2022.ods
# DICION╡RIO/Dicionário_Microdados_Enem_2022.xlsx
# INPUTS/
# INPUTS/INPUT_R_ITENS_PROVA_2022.R
# INPUTS/INPUT_R_MICRODADOS_ENEM_2022.R
# INPUTS/INPUT_R_QUEST_HAB_ESTUDO.R
# INPUTS/INPUT_SAS_ITENS_PROVA_2022.sas
# INPUTS/INPUT_SAS_MICRODADOS_ENEM_2022.sas
# INPUTS/INPUT_SAS_QUEST_HAB_ESTUDO.sas
# INPUTS/INPUT_SPSS_ITENS_PROVA_2022.sps
# INPUTS/INPUT_SPSS_MICRODADOS_ENEM_2022.sps
# INPUTS/INPUT_SPSS_QUEST_HAB_ESTUDO.sps
# LEIA-ME E DOCUMENTOS TÉCNICOS/
# LEIA-ME E DOCUMENTOS TÉCNICOS/Edital_Enem_2022_Digital.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/Edital_Enem_2022_Impresso.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/enem_procedimentos_de_analise.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/entenda_a_sua_nota_no_enem_guia_do_participante (2).pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/Leia_Me_Enem_2022.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/manual_de_redacao_do_enem_2020.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/matriz_referencia_enem.pdf
# PROVAS E GABARITOS/
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_01_DIA_1_AZUL_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_01_DIA_1_AZUL_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_02_DIA_1_AMARELO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_02_DIA_1_AMARELO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_03_DIA_1_BRANCO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_03_DIA_1_BRANCO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_04_DIA_1_ROSA_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_04_DIA_1_ROSA_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_01_DIA_1_AZUL_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_01_DIA_1_AZUL_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_02_DIA_1_AMARELO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_02_DIA_1_AMARELO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_03_DIA_1_BRANCO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_03_DIA_1_BRANCO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_04_DIA_1_ROSA_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_04_DIA_1_ROSA_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_DIGITAL_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_03_DIA_1_BRANCO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_03_DIA_1_BRANCO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_06_DIA_2_CINZA_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_06_DIA_2_CINZA_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_10_DIA_1_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_10_DIA_1_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_12_DIA_2_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_12_DIA_2_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_CAD_12_DIA_2_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_03_DIA_1_BRANCO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_03_DIA_1_BRANCO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_06_DIA_2_CINZA_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_06_DIA_2_CINZA_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_10_DIA_1_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_10_DIA_1_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_12_DIA_2_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_12_DIA_2_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P1_GAB_12_DIA_2_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_03_DIA_1_BRANCO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_03_DIA_1_BRANCO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_06_DIA_2_CINZA_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_06_DIA_2_CINZA_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_CAD_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_03_DIA_1_BRANCO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_03_DIA_1_BRANCO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_06_DIA_2_CINZA_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_06_DIA_2_CINZA_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2022_P2_GAB_11_DIA_2_LARANJA_LEDOR.pdf
# DADOS/
# DADOS/ITENS_PROVA_2022.csv
# DADOS/MICRODADOS_ENEM_2022.csv
# DADOS/QUEST_HAB_ESTUDO.csv

# %% [markdown]
# - **Identificaçáo das colunas**

# %%
with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2022.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2022.csv') as f:
    df = pd.read_csv(f,sep=';',encoding='ISO-8859-1',nrows=5)

# %%
df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            5 non-null      int64
#  1   NU_ANO                  5 non-null      int64
#  2   TP_FAIXA_ETARIA         5 non-null      int64
#  3   TP_SEXO                 5 non-null      object
#  4   TP_ESTADO_CIVIL         5 non-null      int64
#  5   TP_COR_RACA             5 non-null      int64
#  6   TP_NACIONALIDADE        5 non-null      int64
#  7   TP_ST_CONCLUSAO         5 non-null      int64
#  8   TP_ANO_CONCLUIU         5 non-null      int64
#  9   TP_ESCOLA               5 non-null      int64
#  10  TP_ENSINO               0 non-null      float64
#  11  IN_TREINEIRO            5 non-null      int64
#  12  CO_MUNICIPIO_ESC        0 non-null      float64
#  13  NO_MUNICIPIO_ESC        0 non-null      float64
#  14  CO_UF_ESC               0 non-null      float64
#  15  SG_UF_ESC               0 non-null      float64
#  16  TP_DEPENDENCIA_ADM_ESC  0 non-null      float64
#  17  TP_LOCALIZACAO_ESC      0 non-null      float64
#  18  TP_SIT_FUNC_ESC         0 non-null      float64
#  19  CO_MUNICIPIO_PROVA      5 non-null      int64
#  20  NO_MUNICIPIO_PROVA      5 non-null      object
#  21  CO_UF_PROVA             5 non-null      int64
#  22  SG_UF_PROVA             5 non-null      object
#  23  TP_PRESENCA_CN          5 non-null      int64
#  24  TP_PRESENCA_CH          5 non-null      int64
#  25  TP_PRESENCA_LC          5 non-null      int64
#  26  TP_PRESENCA_MT          5 non-null      int64
#  27  CO_PROVA_CN             2 non-null      float64
#  28  CO_PROVA_CH             2 non-null      float64
#  29  CO_PROVA_LC             2 non-null      float64
#  30  CO_PROVA_MT             2 non-null      float64
#  31  NU_NOTA_CN              2 non-null      float64
#  32  NU_NOTA_CH              2 non-null      float64
#  33  NU_NOTA_LC              2 non-null      float64
#  34  NU_NOTA_MT              2 non-null      float64
#  35  TX_RESPOSTAS_CN         2 non-null      object
#  36  TX_RESPOSTAS_CH         2 non-null      object
#  37  TX_RESPOSTAS_LC         2 non-null      object
#  38  TX_RESPOSTAS_MT         2 non-null      object
#  39  TP_LINGUA               5 non-null      int64
#  40  TX_GABARITO_CN          2 non-null      object
#  41  TX_GABARITO_CH          2 non-null      object
#  42  TX_GABARITO_LC          2 non-null      object
#  43  TX_GABARITO_MT          2 non-null      object
#  44  TP_STATUS_REDACAO       2 non-null      float64
#  45  NU_NOTA_COMP1           2 non-null      float64
#  46  NU_NOTA_COMP2           2 non-null      float64
#  47  NU_NOTA_COMP3           2 non-null      float64
#  48  NU_NOTA_COMP4           2 non-null      float64
#  49  NU_NOTA_COMP5           2 non-null      float64
#  50  NU_NOTA_REDACAO         2 non-null      float64
#  51  Q001                    5 non-null      object
#  52  Q002                    5 non-null      object
#  53  Q003                    5 non-null      object
#  54  Q004                    5 non-null      object
#  55  Q005                    5 non-null      int64
#  56  Q006                    5 non-null      object
#  57  Q007                    5 non-null      object
#  58  Q008                    5 non-null      object
#  59  Q009                    5 non-null      object
#  60  Q010                    5 non-null      object
#  61  Q011                    5 non-null      object
#  62  Q012                    5 non-null      object
#  63  Q013                    5 non-null      object
#  64  Q014                    5 non-null      object
#  65  Q015                    5 non-null      object
#  66  Q016                    5 non-null      object
#  67  Q017                    5 non-null      object
#  68  Q018                    5 non-null      object
#  69  Q019                    5 non-null      object
#  70  Q020                    5 non-null      object
#  71  Q021                    5 non-null      object
#  72  Q022                    5 non-null      object
#  73  Q023                    5 non-null      object
#  74  Q024                    5 non-null      object
#  75  Q025                    5 non-null      object
# dtypes: float64(23), int64(18), object(35)
# memory usage: 3.1+ KB

# %%
df[['CO_MUNICIPIO_ESC','SG_UF_ESC','CO_UF_ESC','NO_MUNICIPIO_ESC']]
# Out:
#    CO_MUNICIPIO_ESC  SG_UF_ESC  CO_UF_ESC  NO_MUNICIPIO_ESC
# 0               NaN        NaN        NaN               NaN
# 1               NaN        NaN        NaN               NaN
# 2               NaN        NaN        NaN               NaN
# 3               NaN        NaN        NaN               NaN
# 4               NaN        NaN        NaN               NaN

# %%
colunas = [
'NU_INSCRICAO',
'NU_ANO',
'TP_FAIXA_ETARIA',
'TP_SEXO',
'TP_ESTADO_CIVIL',
'TP_COR_RACA',
'TP_ST_CONCLUSAO',
'TP_ANO_CONCLUIU',
'TP_ESCOLA',
'TP_ENSINO',
'IN_TREINEIRO',
'CO_MUNICIPIO_ESC',
'NO_MUNICIPIO_ESC',
'SG_UF_ESC',
'TP_LOCALIZACAO_ESC',
'CO_MUNICIPIO_PROVA',
'NO_MUNICIPIO_PROVA',
'SG_UF_PROVA',
'NU_NOTA_CN',
'NU_NOTA_CH',
'NU_NOTA_LC',
'NU_NOTA_MT',
'TP_LINGUA',
'NU_NOTA_REDACAO',
'Q001',
'Q002',
'Q003',
'Q004',
'Q005',
'Q006',
'Q007',
'Q008',
'Q009',
'Q010',
'Q011',
'Q012',
'Q013',
'Q014',
'Q015',
'Q016',
'Q017',
'Q018',
'Q019',
'Q020',
'Q021',
'Q022',
'Q023',
'Q024',
'Q025']

# %%
dtype = {
'NU_INSCRICAO':'int64',
'NU_ANO':'category',
'TP_FAIXA_ETARIA':'category',
'TP_SEXO':'category',
'TP_ESTADO_CIVIL':'object',
'TP_COR_RACA':'category',
'TP_ST_CONCLUSAO':'category',
'TP_ANO_CONCLUIU':'category',
'TP_ESCOLA':'category',
'TP_ENSINO':'object',
'IN_TREINEIRO':'category',
'CO_MUNICIPIO_ESC':'float64',
'NO_MUNICIPIO_ESC':'object',
'SG_UF_ESC':'object',
'TP_LOCALIZACAO_ESC':'object',
'CO_MUNICIPIO_PROVA':'float64',
'NO_MUNICIPIO_PROVA':'object',
'SG_UF_PROVA':'object',
'NU_NOTA_CN':'float64',
'NU_NOTA_CH':'float64',
'NU_NOTA_LC':'float64',
'NU_NOTA_MT':'float64',
'TP_LINGUA':'category',
'NU_NOTA_REDACAO':'float64',
'Q001':'category',
'Q002':'category',
'Q003':'category',
'Q004':'category',
'Q005':'float64',
'Q006':'category',
'Q007':'category',
'Q008':'category',
'Q009':'category',
'Q010':'category',
'Q011':'category',
'Q012':'category',
'Q013':'category',
'Q014':'category',
'Q015':'category',
'Q016':'category',
'Q017':'category',
'Q018':'category',
'Q019':'category',
'Q020':'category',
'Q021':'category',
'Q022':'category',
'Q023':'category',
'Q024':'category',
'Q025':'category'}

# %%
columns = list(dtype.keys())
dtype.keys()
# Out:
# dict_keys(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_LOCALIZACAO_ESC', 'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'])

# %% [markdown]
# - **Importar arquivo (apenas as colunas necessárias)**

# %%
# %%time

with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2022.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2022.csv') as f:
    nRows = 0
    dfchunks = []
    for dfchunk in pd.read_csv(f,sep=';',encoding='ISO-8859-1',usecols=columns,dtype=dtype,chunksize=500000):
      nRows = nRows + len(dfchunk)
      print('processed {0}'.format(nRows))
      dfchunks.append(dfchunk)

df = pd.concat(dfchunks)
# Out:
# processed 500000
# processed 1000000
# processed 1500000
# processed 2000000
# processed 2500000
# processed 3000000
# processed 3476105
# CPU times: user 25.5 s, sys: 801 ms, total: 26.3 s
# Wall time: 27.3 s

# %%
df.head()
# Out:
#    NU_INSCRICAO NU_ANO TP_FAIXA_ETARIA TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA  \
# 0  210057943671   2022              14       M               2           2
# 1  210057516120   2022              14       M               2           1
# 2  210057280536   2022               5       F               1           2
# 3  210055724397   2022               6       M               1           3
# 4  210055097896   2022               4       M               0           3
#
#   TP_ST_CONCLUSAO TP_ANO_CONCLUIU TP_ESCOLA TP_ENSINO  ... Q016  Q017 Q018  \
# 0               1               2         1       NaN  ...    B     A    A
# 1               1              16         1       NaN  ...    E     E    B
# 2               1               2         1       NaN  ...    A     A    A
# 3               1               2         1       NaN  ...    B     A    A
# 4               1               1         1       NaN  ...    A     A    A
#
#   Q019 Q020  Q021 Q022 Q023  Q024  Q025
# 0    A    A     A    A    A     A     A
# 1    E    B     B    E    B     E     B
# 2    A    A     A    C    A     A     B
# 3    C    A     A    C    B     B     B
# 4    A    A     A    B    A     A     A
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (3476105, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3476105 entries, 0 to 3476104
# Data columns (total 49 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   NU_INSCRICAO        int64
#  1   NU_ANO              category
#  2   TP_FAIXA_ETARIA     category
#  3   TP_SEXO             category
#  4   TP_ESTADO_CIVIL     object
#  5   TP_COR_RACA         category
#  6   TP_ST_CONCLUSAO     category
#  7   TP_ANO_CONCLUIU     category
#  8   TP_ESCOLA           category
#  9   TP_ENSINO           object
#  10  IN_TREINEIRO        category
#  11  CO_MUNICIPIO_ESC    float64
#  12  NO_MUNICIPIO_ESC    object
#  13  SG_UF_ESC           object
#  14  TP_LOCALIZACAO_ESC  object
#  15  CO_MUNICIPIO_PROVA  float64
#  16  NO_MUNICIPIO_PROVA  object
#  17  SG_UF_PROVA         object
#  18  NU_NOTA_CN          float64
#  19  NU_NOTA_CH          float64
#  20  NU_NOTA_LC          float64
#  21  NU_NOTA_MT          float64
#  22  TP_LINGUA           category
#  23  NU_NOTA_REDACAO     float64
#  24  Q001                category
#  25  Q002                category
#  26  Q003                category
#  27  Q004                category
#  28  Q005                float64
#  29  Q006                category
#  30  Q007                category
#  31  Q008                category
#  32  Q009                category
#  33  Q010                category
#  34  Q011                category
#  35  Q012                category
#  36  Q013                category
#  37  Q014                category
#  38  Q015                category
#  39  Q016                category
#  40  Q017                category
#  41  Q018                category
#  42  Q019                category
#  43  Q020                category
#  44  Q021                category
#  45  Q022                category
#  46  Q023                category
#  47  Q024                category
#  48  Q025                category
# dtypes: category(33), float64(8), int64(1), object(7)
# memory usage: 533.7+ MB

# %% [markdown]
# **Validação**

# %%
tb_desc = df.describe(include='all')
tb_desc.to_excel('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Desc_1_2022.xlsx')

# %% [markdown]
# # **Critérios de Inclusão/Exclusão**

# %%
tb1 = df[['IN_TREINEIRO','NU_ANO']].groupby('IN_TREINEIRO').count()
display(tb1)
# Out:
#                NU_ANO
# IN_TREINEIRO
# 0             2963373
# 1              512732

# %%
tb2 = df[['TP_ST_CONCLUSAO','NU_ANO']].groupby('TP_ST_CONCLUSAO').count()
display(tb2)
# Out:
#                   NU_ANO
# TP_ST_CONCLUSAO
# 1                1633253
# 2                1317560
# 3                 512732
# 4                  12560

# %%
tb3 = pd.crosstab(df.IN_TREINEIRO,df.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb3)
# Out:
# TP_ST_CONCLUSAO        1        2       3      4      All
# IN_TREINEIRO
# 0                1633253  1317560       0  12560  2963373
# 1                      0        0  512732      0   512732
# All              1633253  1317560  512732  12560  3476105

# %% [markdown]
# - IN_TREINEIRO: Treineiro

# %%
df_f = df.loc[df['IN_TREINEIRO'] == '0']
df_f.shape
# Out:
# (2963373, 49)

# %% [markdown]
# - TP_ST_CONCLUSAO: situação da conclusão do Ensino Médio

# %%
df_f = df_f.loc[(df_f['TP_ST_CONCLUSAO'] != '3') & (df_f['TP_ST_CONCLUSAO'] != '4')]
df_f.shape
# Out:
# (2950813, 49)

# %%
pd.crosstab(df_f.IN_TREINEIRO,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
# Out:
# TP_ST_CONCLUSAO        1        2  3  4      All
# IN_TREINEIRO
# 0                1633253  1317560  0  0  2950813
# 1                      0        0  0  0        0
# All              1633253  1317560  0  0  2950813

# %% [markdown]
# # **Análise de Dados Missings**

# %% [markdown]
# - Verificação

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO                0
# NU_ANO                      0
# TP_FAIXA_ETARIA             0
# TP_SEXO                     0
# TP_ESTADO_CIVIL             0
# TP_COR_RACA                 0
# TP_ST_CONCLUSAO             0
# TP_ANO_CONCLUIU             0
# TP_ESCOLA                   0
# TP_ENSINO             1688069
# IN_TREINEIRO                0
# CO_MUNICIPIO_ESC      1998869
# NO_MUNICIPIO_ESC      1998869
# SG_UF_ESC             1998869
# TP_LOCALIZACAO_ESC    1998869
# CO_MUNICIPIO_PROVA          0
# NO_MUNICIPIO_PROVA          0
# SG_UF_PROVA                 0
# NU_NOTA_CN            1024304
# NU_NOTA_CH             918643
# NU_NOTA_LC             918643
# NU_NOTA_MT            1024304
# TP_LINGUA                   0
# NU_NOTA_REDACAO        918643
# Q001                        0
# Q002                        0
# Q003                        0
# Q004                        0
# Q005                        0
# Q006                        0
# Q007                        0
# Q008                        0
# Q009                        0
# Q010                        0
# Q011                        0
# Q012                        0
# Q013                        0
# Q014                        0
# Q015                        0
# Q016                        0
# Q017                        0
# Q018                        0
# Q019                        0
# Q020                        0
# Q021                        0
# Q022                        0
# Q023                        0
# Q024                        0
# Q025                        0
# dtype: int64

# %% [markdown]
# - Inclusão da categoria Missing apenas nos Inputs

# %% [markdown]
# - Tipo de Ensino

# %%
df_f['TP_ENSINO'].fillna('9', inplace=True)

# %%
df_f[['TP_ENSINO','NU_ANO']].groupby('TP_ENSINO').count()
# Out:
#             NU_ANO
# TP_ENSINO
# 1          1255177
# 2             7567
# 9          1688069

# %%
df_f[['TP_ENSINO','NU_ANO']].groupby('TP_ENSINO').count().sum()
# Out:
# NU_ANO    2950813
# dtype: int64

# %% [markdown]
# - Variáveis relacionadas à Escola

# %%
df_f['CO_MUNICIPIO_ESC'].fillna('-1', inplace=True)
df_f['NO_MUNICIPIO_ESC'].fillna('-1', inplace=True)
df_f['SG_UF_ESC'].fillna('-1', inplace=True)
df_f['TP_LOCALIZACAO_ESC'].fillna('-1', inplace=True)

# %%
df_f[['CO_MUNICIPIO_ESC','NU_ANO']].groupby('CO_MUNICIPIO_ESC').count()
# Out:
#                    NU_ANO
# CO_MUNICIPIO_ESC
# 1100015.0             102
# 1100023.0             555
# 1100031.0              30
# 1100049.0             678
# 1100056.0              70
# ...                   ...
# 5222054.0              65
# 5222203.0              38
# 5222302.0              46
# 5300108.0           19348
# -1                1998869
#
# [5538 rows x 1 columns]

# %%
df_f[['NO_MUNICIPIO_ESC','NU_ANO']].groupby('NO_MUNICIPIO_ESC').count()
# Out:
#                       NU_ANO
# NO_MUNICIPIO_ESC
# -1                   1998869
# Abadia de Goiás           60
# Abadia dos Dourados       18
# Abadiânia                153
# Abaetetuba               830
# ...                      ...
# Áurea                      4
# Ângulo                    16
# Érico Cardoso             17
# Óbidos                   137
# Óleo                      11
#
# [5266 rows x 1 columns]

# %%
df_f[['SG_UF_ESC','NU_ANO']].groupby('SG_UF_ESC').count()
# Out:
#             NU_ANO
# SG_UF_ESC
# -1         1998869
# AC            4291
# AL           15685
# AM           27737
# AP            3869
# BA           44483
# CE          102972
# DF           19348
# ES           19998
# GO           47563
# MA           27679
# MG           68869
# MS           13105
# MT           16877
# PA           34897
# PB           21483
# PE           43562
# PI           16296
# PR           50307
# RJ           68435
# RN           16701
# RO            9687
# RR            2219
# RS           41842
# SC           31316
# SE           10802
# SP          184295
# TO            7626

# %%
df_f[['TP_LOCALIZACAO_ESC','NU_ANO']].groupby('TP_LOCALIZACAO_ESC').count()
# Out:
#                      NU_ANO
# TP_LOCALIZACAO_ESC
# -1                  1998869
# 1                    918409
# 2                     33535

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO                0
# NU_ANO                      0
# TP_FAIXA_ETARIA             0
# TP_SEXO                     0
# TP_ESTADO_CIVIL             0
# TP_COR_RACA                 0
# TP_ST_CONCLUSAO             0
# TP_ANO_CONCLUIU             0
# TP_ESCOLA                   0
# TP_ENSINO                   0
# IN_TREINEIRO                0
# CO_MUNICIPIO_ESC            0
# NO_MUNICIPIO_ESC            0
# SG_UF_ESC                   0
# TP_LOCALIZACAO_ESC          0
# CO_MUNICIPIO_PROVA          0
# NO_MUNICIPIO_PROVA          0
# SG_UF_PROVA                 0
# NU_NOTA_CN            1024304
# NU_NOTA_CH             918643
# NU_NOTA_LC             918643
# NU_NOTA_MT            1024304
# TP_LINGUA                   0
# NU_NOTA_REDACAO        918643
# Q001                        0
# Q002                        0
# Q003                        0
# Q004                        0
# Q005                        0
# Q006                        0
# Q007                        0
# Q008                        0
# Q009                        0
# Q010                        0
# Q011                        0
# Q012                        0
# Q013                        0
# Q014                        0
# Q015                        0
# Q016                        0
# Q017                        0
# Q018                        0
# Q019                        0
# Q020                        0
# Q021                        0
# Q022                        0
# Q023                        0
# Q024                        0
# Q025                        0
# dtype: int64

# %% [markdown]
# - Exclusão de informações missings no Target

# %%
df_f.dropna(subset=['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'], inplace=True, axis=0) # Axis = 0 exclui as linhas, =1, as colunas

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO          0
# NU_ANO                0
# TP_FAIXA_ETARIA       0
# TP_SEXO               0
# TP_ESTADO_CIVIL       0
# TP_COR_RACA           0
# TP_ST_CONCLUSAO       0
# TP_ANO_CONCLUIU       0
# TP_ESCOLA             0
# TP_ENSINO             0
# IN_TREINEIRO          0
# CO_MUNICIPIO_ESC      0
# NO_MUNICIPIO_ESC      0
# SG_UF_ESC             0
# TP_LOCALIZACAO_ESC    0
# CO_MUNICIPIO_PROVA    0
# NO_MUNICIPIO_PROVA    0
# SG_UF_PROVA           0
# NU_NOTA_CN            0
# NU_NOTA_CH            0
# NU_NOTA_LC            0
# NU_NOTA_MT            0
# TP_LINGUA             0
# NU_NOTA_REDACAO       0
# Q001                  0
# Q002                  0
# Q003                  0
# Q004                  0
# Q005                  0
# Q006                  0
# Q007                  0
# Q008                  0
# Q009                  0
# Q010                  0
# Q011                  0
# Q012                  0
# Q013                  0
# Q014                  0
# Q015                  0
# Q016                  0
# Q017                  0
# Q018                  0
# Q019                  0
# Q020                  0
# Q021                  0
# Q022                  0
# Q023                  0
# Q024                  0
# Q025                  0
# dtype: int64

# %%
df_f.shape
# Out:
# (1920850, 49)

# %%
df_f.isnull().sum()/df_f.shape[0]*100 # % de nulos entre as questões
# Out:
# NU_INSCRICAO          0.0
# NU_ANO                0.0
# TP_FAIXA_ETARIA       0.0
# TP_SEXO               0.0
# TP_ESTADO_CIVIL       0.0
# TP_COR_RACA           0.0
# TP_ST_CONCLUSAO       0.0
# TP_ANO_CONCLUIU       0.0
# TP_ESCOLA             0.0
# TP_ENSINO             0.0
# IN_TREINEIRO          0.0
# CO_MUNICIPIO_ESC      0.0
# NO_MUNICIPIO_ESC      0.0
# SG_UF_ESC             0.0
# TP_LOCALIZACAO_ESC    0.0
# CO_MUNICIPIO_PROVA    0.0
# NO_MUNICIPIO_PROVA    0.0
# SG_UF_PROVA           0.0
# NU_NOTA_CN            0.0
# NU_NOTA_CH            0.0
# NU_NOTA_LC            0.0
# NU_NOTA_MT            0.0
# TP_LINGUA             0.0
# NU_NOTA_REDACAO       0.0
# Q001                  0.0
# Q002                  0.0
# Q003                  0.0
# Q004                  0.0
# Q005                  0.0
# Q006                  0.0
# Q007                  0.0
# Q008                  0.0
# Q009                  0.0
# Q010                  0.0
# Q011                  0.0
# Q012                  0.0
# Q013                  0.0
# Q014                  0.0
# Q015                  0.0
# Q016                  0.0
# Q017                  0.0
# Q018                  0.0
# Q019                  0.0
# Q020                  0.0
# Q021                  0.0
# Q022                  0.0
# Q023                  0.0
# Q024                  0.0
# Q025                  0.0
# dtype: float64

# %%
df_f.shape
# Out:
# (1920850, 49)

# %% [markdown]
# # **Padronização das Variáveis**

# %% [markdown]
# - Estado Civil

# %%
df_f.TP_ESTADO_CIVIL.value_counts()
# Out:
# 1    1758370
# 2      76813
# 0      59576
# 3      24338
# 4       1753
# Name: TP_ESTADO_CIVIL, dtype: int64

# %% [markdown]
# - TP_ESCOLA

# %%
df_f.TP_ESCOLA.value_counts()
# Out:
# 1    963119
# 2    760853
# 3    196878
# Name: TP_ESCOLA, dtype: int64

# %% [markdown]
# # **Análise Descritiva**

# %% [markdown]
# - **Variáveis Quantitiativas**

# %%
round(df_f.describe(include=None),1)
# Out:
#        NU_INSCRICAO  CO_MUNICIPIO_PROVA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# count  1.920850e+06           1920850.0   1920850.0   1920850.0   1920850.0
# mean   2.100563e+11           3099308.9       497.5       530.7       520.0
# std    1.019283e+06            988439.1        73.3        80.9        76.9
# min    2.100545e+11           1100015.0         0.0         0.0         0.0
# 25%    2.100554e+11           2408003.0       440.9       479.6       470.9
# 50%    2.100563e+11           3121605.0       486.8       532.5       527.5
# 75%    2.100571e+11           3549904.0       545.8       585.8       575.5
# max    2.100580e+11           5300108.0       875.3       839.2       801.0
#
#        NU_NOTA_MT  NU_NOTA_REDACAO       Q005
# count   1920850.0        1920850.0  1920850.0
# mean        542.1            627.7        3.8
# std         117.4            203.8        1.3
# min           0.0              0.0        1.0
# 25%         447.5            540.0        3.0
# 50%         529.1            620.0        4.0
# 75%         622.2            780.0        4.0
# max         985.7           1000.0       20.0

# %% [markdown]
# - **Variáveis Qualitativas**

# %%
df_f.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU',
#        'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_LOCALIZACAO_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN',
#        'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015',
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object')

# %%
df_varquali = df_f[['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO',
             'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', #'NO_MUNICIPIO_ESC', 'NO_MUNICIPIO_PROVA',
             'SG_UF_ESC', 'TP_LOCALIZACAO_ESC', 'SG_UF_PROVA', 'TP_LINGUA',
             'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012',
             'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023',
             'Q024', 'Q025']]

# %%
dist_freq_quali = pd.DataFrame()
dist_freq_quali_t = list()

for column in df_varquali:
  freq_var = df_varquali[column].value_counts().sort_index()
  perc_var = df_varquali[column].value_counts(normalize=True).sort_index() * 100
  dist_freq_quali_ = pd.DataFrame({'n': freq_var,
                                   '(%)': perc_var})
  dist_freq_quali_t_ = dist_freq_quali_['n'].sum()

  dist_freq_quali = pd.concat([dist_freq_quali, dist_freq_quali_])
  dist_freq_quali_t.append(dist_freq_quali_t_)

dist_freq_quali.to_excel('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Desc_2_2022.xlsx')

# %% [markdown]
# # **Análise Gráfica (Target)**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# > **Boxplot**

# %%
labels = ['','CN','CH','LC','MT','Redação']

df_f.boxplot(column = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'],
             showmeans=True)
plt.xlabel('Competência')
plt.xticks(range(len(labels)),labels, rotation=0)
plt.ylabel('Nota')
plt.title('2022')
plt.xlim()
plt.grid()
plt.savefig('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Notas_2022.png')
plt.show()

# %%
selcol = df_f[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']]

# %%
sns.set_theme(style="ticks")
sns.pairplot(selcol)

# %% [markdown]
# # **Análise de Correlação**

# %% [markdown]
# - Entre as variáveis respostas

# %%
corr1 = selcol.corr(method='pearson')
print(corr1)
corr2 = selcol.corr(method='spearman')
print(corr2)

plt.imshow(corr2, cmap='hot', interpolation='none')
plt.colorbar()
plt.title('2022')
plt.xticks(range(len(corr2)), rotation=90, labels=['CN','CH','LC','MT','Redação'])
plt.yticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação']);
plt.show()
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_NOTA_CN         1.000000    0.616792    0.580420    0.620977
# NU_NOTA_CH         0.616792    1.000000    0.738481    0.633259
# NU_NOTA_LC         0.580420    0.738481    1.000000    0.598916
# NU_NOTA_MT         0.620977    0.633259    0.598916    1.000000
# NU_NOTA_REDACAO    0.449273    0.511675    0.513970    0.497359
#
#                  NU_NOTA_REDACAO
# NU_NOTA_CN              0.449273
# NU_NOTA_CH              0.511675
# NU_NOTA_LC              0.513970
# NU_NOTA_MT              0.497359
# NU_NOTA_REDACAO         1.000000
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_NOTA_CN         1.000000    0.603873    0.580262    0.546964
# NU_NOTA_CH         0.603873    1.000000    0.760866    0.628790
# NU_NOTA_LC         0.580262    0.760866    1.000000    0.602593
# NU_NOTA_MT         0.546964    0.628790    0.602593    1.000000
# NU_NOTA_REDACAO    0.468363    0.552123    0.536776    0.523759
#
#                  NU_NOTA_REDACAO
# NU_NOTA_CN              0.468363
# NU_NOTA_CH              0.552123
# NU_NOTA_LC              0.536776
# NU_NOTA_MT              0.523759
# NU_NOTA_REDACAO         1.000000

# %%
plt.figure(figsize=(15,8))
matriz = np.triu(corr2)
sns.heatmap(corr2, mask= matriz, annot=True, cmap='YlGnBu')
plt.title('2022')
plt.xticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação'])
plt.yticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação']);
plt.savefig("/content/drive/MyDrive/MBA_TCC/RESULTADOS/Notas_2022 - Matriz de Correlacao (S).png")
plt.show()

# %% [markdown]
# # **Validações**

# %%
tb4 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ENSINO, margins=True, dropna=False)
display(tb4)
# Out:
# TP_ENSINO       1     2       9      All
# SG_UF_ESC
# -1         255282  1951  970702  1227935
# AC           2926    11      76     3013
# AL          10967    51     199    11217
# AM          13711    55     367    14133
# AP           2779     5      91     2875
# BA          32568   183     627    33378
# CE          70322   220     798    71340
# DF          15424    35     312    15771
# ES          14872    43     437    15352
# GO          27057   133     673    27863
# MA          20114    76     368    20558
# MG          52695   144     783    53622
# MS           9208    37     126     9371
# MT          11778    62     200    12040
# PA          25403   138     647    26188
# PB          15475    97     347    15919
# PE          31423   123     514    32060
# PI          12748    69     274    13091
# PR          36018   159     314    36491
# RJ          50627   226    1059    51912
# RN          13302    44     378    13724
# RO           5904    23     204     6131
# RR           1359     4      24     1387
# RS          31058    84     526    31668
# SC          22846    45     174    23065
# SE           8185    33     178     8396
# SP         135578   450    1235   137263
# TO           4977    26      84     5087
# All        934606  4527  981717  1920850

# %%
tb5 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ANO_CONCLUIU, margins=True, dropna=False)
display(tb5)
# Out:
# TP_ANO_CONCLUIU        0       1     10     11     12     13    14    15  \
# SG_UF_ESC
# -1                343894  297575  15668  12437  11450  10182  8669  8330
# AC                  3013       0      0      0      0      0     0     0
# AL                 11217       0      0      0      0      0     0     0
# AM                 14133       0      0      0      0      0     0     0
# AP                  2875       0      0      0      0      0     0     0
# BA                 33378       0      0      0      0      0     0     0
# CE                 71340       0      0      0      0      0     0     0
# DF                 15771       0      0      0      0      0     0     0
# ES                 15352       0      0      0      0      0     0     0
# GO                 27863       0      0      0      0      0     0     0
# MA                 20558       0      0      0      0      0     0     0
# MG                 53622       0      0      0      0      0     0     0
# MS                  9371       0      0      0      0      0     0     0
# MT                 12040       0      0      0      0      0     0     0
# PA                 26188       0      0      0      0      0     0     0
# PB                 15919       0      0      0      0      0     0     0
# PE                 32060       0      0      0      0      0     0     0
# PI                 13091       0      0      0      0      0     0     0
# PR                 36491       0      0      0      0      0     0     0
# RJ                 51912       0      0      0      0      0     0     0
# RN                 13724       0      0      0      0      0     0     0
# RO                  6131       0      0      0      0      0     0     0
# RR                  1387       0      0      0      0      0     0     0
# RS                 31668       0      0      0      0      0     0     0
# SC                 23065       0      0      0      0      0     0     0
# SE                  8396       0      0      0      0      0     0     0
# SP                137263       0      0      0      0      0     0     0
# TO                  5087       0      0      0      0      0     0     0
# All              1036809  297575  15668  12437  11450  10182  8669  8330
#
# TP_ANO_CONCLUIU     16       2      3      4      5      6      7      8  \
# SG_UF_ESC
# -1               70485  131246  99233  66101  49544  35287  27668  22275
# AC                   0       0      0      0      0      0      0      0
# AL                   0       0      0      0      0      0      0      0
# AM                   0       0      0      0      0      0      0      0
# AP                   0       0      0      0      0      0      0      0
# BA                   0       0      0      0      0      0      0      0
# CE                   0       0      0      0      0      0      0      0
# DF                   0       0      0      0      0      0      0      0
# ES                   0       0      0      0      0      0      0      0
# GO                   0       0      0      0      0      0      0      0
# MA                   0       0      0      0      0      0      0      0
# MG                   0       0      0      0      0      0      0      0
# MS                   0       0      0      0      0      0      0      0
# MT                   0       0      0      0      0      0      0      0
# PA                   0       0      0      0      0      0      0      0
# PB                   0       0      0      0      0      0      0      0
# PE                   0       0      0      0      0      0      0      0
# PI                   0       0      0      0      0      0      0      0
# PR                   0       0      0      0      0      0      0      0
# RJ                   0       0      0      0      0      0      0      0
# RN                   0       0      0      0      0      0      0      0
# RO                   0       0      0      0      0      0      0      0
# RR                   0       0      0      0      0      0      0      0
# RS                   0       0      0      0      0      0      0      0
# SC                   0       0      0      0      0      0      0      0
# SE                   0       0      0      0      0      0      0      0
# SP                   0       0      0      0      0      0      0      0
# TO                   0       0      0      0      0      0      0      0
# All              70485  131246  99233  66101  49544  35287  27668  22275
#
# TP_ANO_CONCLUIU      9      All
# SG_UF_ESC
# -1               17891  1227935
# AC                   0     3013
# AL                   0    11217
# AM                   0    14133
# AP                   0     2875
# BA                   0    33378
# CE                   0    71340
# DF                   0    15771
# ES                   0    15352
# GO                   0    27863
# MA                   0    20558
# MG                   0    53622
# MS                   0     9371
# MT                   0    12040
# PA                   0    26188
# PB                   0    15919
# PE                   0    32060
# PI                   0    13091
# PR                   0    36491
# RJ                   0    51912
# RN                   0    13724
# RO                   0     6131
# RR                   0     1387
# RS                   0    31668
# SC                   0    23065
# SE                   0     8396
# SP                   0   137263
# TO                   0     5087
# All              17891  1920850

# %%
tb6 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb6)
# Out:
# TP_ST_CONCLUSAO       1       2  3  4      All
# SG_UF_ESC
# -1               963119  264816  0  0  1227935
# AC                    0    3013  0  0     3013
# AL                    0   11217  0  0    11217
# AM                    0   14133  0  0    14133
# AP                    0    2875  0  0     2875
# BA                    0   33378  0  0    33378
# CE                    0   71340  0  0    71340
# DF                    0   15771  0  0    15771
# ES                    0   15352  0  0    15352
# GO                    0   27863  0  0    27863
# MA                    0   20558  0  0    20558
# MG                    0   53622  0  0    53622
# MS                    0    9371  0  0     9371
# MT                    0   12040  0  0    12040
# PA                    0   26188  0  0    26188
# PB                    0   15919  0  0    15919
# PE                    0   32060  0  0    32060
# PI                    0   13091  0  0    13091
# PR                    0   36491  0  0    36491
# RJ                    0   51912  0  0    51912
# RN                    0   13724  0  0    13724
# RO                    0    6131  0  0     6131
# RR                    0    1387  0  0     1387
# RS                    0   31668  0  0    31668
# SC                    0   23065  0  0    23065
# SE                    0    8396  0  0     8396
# SP                    0  137263  0  0   137263
# TO                    0    5087  0  0     5087
# All              963119  957731  0  0  1920850

# %%
tb7 = pd.crosstab(df_f.TP_ESCOLA,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb7)
# Out:
# TP_ST_CONCLUSAO       1       2  3  4      All
# TP_ESCOLA
# 1                963119       0  0  0   963119
# 2                     0  760853  0  0   760853
# 3                     0  196878  0  0   196878
# All              963119  957731  0  0  1920850

# %% [markdown]
# # **Exclusão de Colunas**

# %%
df_f.drop(['IN_TREINEIRO'], axis = 1, inplace = True)
df_f.shape
# Out:
# (1920850, 48)

# %% [markdown]
# # **Verificação de Duplicidade na Base Final**

# %%
df_f.NU_INSCRICAO.unique()
# Out:
# array([210057280536, 210055724397, 210055778089, ..., 210055668087,
#        210055303118, 210056699189])

# %%
df_f.shape
# Out:
# (1920850, 48)

# %% [markdown]
# # **Exportar base final**

# %%
df_f.to_csv('/content/drive/MyDrive/MBA_TCC/DADOS/df_f_2022.csv', index=False)

# %%
#selcol.to_csv('/content/drive/MyDrive/MBA_TCC/DADOS/notas_2022.csv', index=False)
