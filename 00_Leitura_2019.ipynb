# %% [markdown]
# <a href="https://colab.research.google.com/github/Adriana-FLW/MBA_TCC/blob/main/00_Leitura_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ENEM 2019**

# %% [markdown]
# # Biblioteca

# %%
import pandas as pd
import zipfile

# %% [markdown]
# # Importar Dados

# %% [markdown]
# - **Localizar microdados**

# %%
with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2019.zip') as z:
  print(*z.namelist(),sep='\n')
# Out:
# INPUTS/
# INPUTS/INPUT_R_ITENS_PROVA_2019.R
# INPUTS/INPUT_R_MICRODADOS_ENEM_2019.R
# INPUTS/INPUT_SAS_ITENS_PROVA_2019.sas
# INPUTS/INPUT_SAS_MICRODADOS_ENEM_2019.sas
# INPUTS/INPUT_SPSS_ITENS_PROVA_2019.sps
# INPUTS/INPUT_SPSS_MICRODADOS_ENEM_2019.sps
# LEIA-ME E DOCUMENTOS TÉCNICOS/
# LEIA-ME E DOCUMENTOS TÉCNICOS/Edital_enem_2019.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/enem_procedimentos_de_analise.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/entenda_a_sua_nota_no_enem_guia_do_participante.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/Leia_Me_Enem_2019.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/manual_de_redacao_do_enem_2019.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/matriz_referencia_enem.pdf
# PROVAS E GABARITOS/
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_02_DIA_1_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_02_DIA_1_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_06_DIA_2_CINZA_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_06_DIA_2_CINZA_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_CAD_12_DIA_2_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_02_DIA_1_AMARELO.pdf.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_02_DIA_1_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_02_DIA_1_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_06_DIA_2_CINZA_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_06_DIA_2_CINZA_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P1_GAB_12_DIA_2_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_01_DIA_1_AZUL_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_01_DIA_1_AZUL_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_05_DIA_2_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_05_DIA_2_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_CAD_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_01_DIA_1_AZUL_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_01_DIA_1_AZUL_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_05_DIA_2_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_05_DIA_2_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2019_P2_GAB_11_DIA_2_LARANJA_LEDOR.pdf
# DADOS/
# DADOS/ITENS_PROVA_2019.csv
# DADOS/MICRODADOS_ENEM_2019.csv
# DICION╡RIO/
# DICION╡RIO/Dicionário_Microdados_Enem_2019.ods
# DICION╡RIO/Dicionário_Microdados_Enem_2019.xlsx

# %% [markdown]
# - **Identificaçáo das colunas**

# %%
with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2019.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2019.csv') as f:
    df = pd.read_csv(f,sep=';',encoding='ISO-8859-1',nrows=5)

# %%
df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            5 non-null      int64
#  1   NU_ANO                  5 non-null      int64
#  2   TP_FAIXA_ETARIA         5 non-null      int64
#  3   TP_SEXO                 5 non-null      object
#  4   TP_ESTADO_CIVIL         5 non-null      int64
#  5   TP_COR_RACA             5 non-null      int64
#  6   TP_NACIONALIDADE        5 non-null      int64
#  7   TP_ST_CONCLUSAO         5 non-null      int64
#  8   TP_ANO_CONCLUIU         5 non-null      int64
#  9   TP_ESCOLA               5 non-null      int64
#  10  TP_ENSINO               3 non-null      float64
#  11  IN_TREINEIRO            5 non-null      int64
#  12  CO_MUNICIPIO_ESC        0 non-null      float64
#  13  NO_MUNICIPIO_ESC        0 non-null      float64
#  14  CO_UF_ESC               0 non-null      float64
#  15  SG_UF_ESC               0 non-null      float64
#  16  TP_DEPENDENCIA_ADM_ESC  0 non-null      float64
#  17  TP_LOCALIZACAO_ESC      0 non-null      float64
#  18  TP_SIT_FUNC_ESC         0 non-null      float64
#  19  CO_MUNICIPIO_PROVA      5 non-null      int64
#  20  NO_MUNICIPIO_PROVA      5 non-null      object
#  21  CO_UF_PROVA             5 non-null      int64
#  22  SG_UF_PROVA             5 non-null      object
#  23  TP_PRESENCA_CN          5 non-null      int64
#  24  TP_PRESENCA_CH          5 non-null      int64
#  25  TP_PRESENCA_LC          5 non-null      int64
#  26  TP_PRESENCA_MT          5 non-null      int64
#  27  CO_PROVA_CN             2 non-null      float64
#  28  CO_PROVA_CH             2 non-null      float64
#  29  CO_PROVA_LC             2 non-null      float64
#  30  CO_PROVA_MT             2 non-null      float64
#  31  NU_NOTA_CN              2 non-null      float64
#  32  NU_NOTA_CH              2 non-null      float64
#  33  NU_NOTA_LC              2 non-null      float64
#  34  NU_NOTA_MT              2 non-null      float64
#  35  TX_RESPOSTAS_CN         2 non-null      object
#  36  TX_RESPOSTAS_CH         2 non-null      object
#  37  TX_RESPOSTAS_LC         2 non-null      object
#  38  TX_RESPOSTAS_MT         2 non-null      object
#  39  TP_LINGUA               5 non-null      int64
#  40  TX_GABARITO_CN          2 non-null      object
#  41  TX_GABARITO_CH          2 non-null      object
#  42  TX_GABARITO_LC          2 non-null      object
#  43  TX_GABARITO_MT          2 non-null      object
#  44  TP_STATUS_REDACAO       2 non-null      float64
#  45  NU_NOTA_COMP1           2 non-null      float64
#  46  NU_NOTA_COMP2           2 non-null      float64
#  47  NU_NOTA_COMP3           2 non-null      float64
#  48  NU_NOTA_COMP4           2 non-null      float64
#  49  NU_NOTA_COMP5           2 non-null      float64
#  50  NU_NOTA_REDACAO         2 non-null      float64
#  51  Q001                    5 non-null      object
#  52  Q002                    5 non-null      object
#  53  Q003                    5 non-null      object
#  54  Q004                    5 non-null      object
#  55  Q005                    5 non-null      int64
#  56  Q006                    5 non-null      object
#  57  Q007                    5 non-null      object
#  58  Q008                    5 non-null      object
#  59  Q009                    5 non-null      object
#  60  Q010                    5 non-null      object
#  61  Q011                    5 non-null      object
#  62  Q012                    5 non-null      object
#  63  Q013                    5 non-null      object
#  64  Q014                    5 non-null      object
#  65  Q015                    5 non-null      object
#  66  Q016                    5 non-null      object
#  67  Q017                    5 non-null      object
#  68  Q018                    5 non-null      object
#  69  Q019                    5 non-null      object
#  70  Q020                    5 non-null      object
#  71  Q021                    5 non-null      object
#  72  Q022                    5 non-null      object
#  73  Q023                    5 non-null      object
#  74  Q024                    5 non-null      object
#  75  Q025                    5 non-null      object
# dtypes: float64(23), int64(18), object(35)
# memory usage: 3.1+ KB

# %%
df[['CO_MUNICIPIO_ESC','SG_UF_ESC','CO_UF_ESC','NO_MUNICIPIO_ESC']]
# Out:
#    CO_MUNICIPIO_ESC  SG_UF_ESC  CO_UF_ESC  NO_MUNICIPIO_ESC
# 0               NaN        NaN        NaN               NaN
# 1               NaN        NaN        NaN               NaN
# 2               NaN        NaN        NaN               NaN
# 3               NaN        NaN        NaN               NaN
# 4               NaN        NaN        NaN               NaN

# %%
colunas = [
'NU_INSCRICAO',
'NU_ANO',
'TP_FAIXA_ETARIA',
'TP_SEXO',
'TP_ESTADO_CIVIL',
'TP_COR_RACA',
'TP_ST_CONCLUSAO',
'TP_ANO_CONCLUIU',
'TP_ESCOLA',
'TP_ENSINO',
'IN_TREINEIRO',
'CO_MUNICIPIO_ESC',
'NO_MUNICIPIO_ESC',
'SG_UF_ESC',
'TP_LOCALIZACAO_ESC',
'CO_MUNICIPIO_PROVA',
'NO_MUNICIPIO_PROVA',
'SG_UF_PROVA',
'NU_NOTA_CN',
'NU_NOTA_CH',
'NU_NOTA_LC',
'NU_NOTA_MT',
'TP_LINGUA',
'NU_NOTA_REDACAO',
'Q001',
'Q002',
'Q003',
'Q004',
'Q005',
'Q006',
'Q007',
'Q008',
'Q009',
'Q010',
'Q011',
'Q012',
'Q013',
'Q014',
'Q015',
'Q016',
'Q017',
'Q018',
'Q019',
'Q020',
'Q021',
'Q022',
'Q023',
'Q024',
'Q025']

# %%
dtype = {
'NU_INSCRICAO':'int64',
'NU_ANO':'category',
'TP_FAIXA_ETARIA':'category',
'TP_SEXO':'category',
'TP_ESTADO_CIVIL':'object',
'TP_COR_RACA':'category',
'TP_ST_CONCLUSAO':'category',
'TP_ANO_CONCLUIU':'category',
'TP_ESCOLA':'category',
'TP_ENSINO':'object',
'IN_TREINEIRO':'category',
'CO_MUNICIPIO_ESC':'float64',
'NO_MUNICIPIO_ESC':'object',
'SG_UF_ESC':'object',
'TP_LOCALIZACAO_ESC':'object',
'CO_MUNICIPIO_PROVA':'float64',
'NO_MUNICIPIO_PROVA':'object',
'SG_UF_PROVA':'object',
'NU_NOTA_CN':'float64',
'NU_NOTA_CH':'float64',
'NU_NOTA_LC':'float64',
'NU_NOTA_MT':'float64',
'TP_LINGUA':'category',
'NU_NOTA_REDACAO':'float64',
'Q001':'category',
'Q002':'category',
'Q003':'category',
'Q004':'category',
'Q005':'float64',
'Q006':'category',
'Q007':'category',
'Q008':'category',
'Q009':'category',
'Q010':'category',
'Q011':'category',
'Q012':'category',
'Q013':'category',
'Q014':'category',
'Q015':'category',
'Q016':'category',
'Q017':'category',
'Q018':'category',
'Q019':'category',
'Q020':'category',
'Q021':'category',
'Q022':'category',
'Q023':'category',
'Q024':'category',
'Q025':'category'}

# %%
columns = list(dtype.keys())
dtype.keys()
# Out:
# dict_keys(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_LOCALIZACAO_ESC', 'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'])

# %% [markdown]
# - **Importar arquivo (apenas as colunas necessárias)**

# %%
# %%time

with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2019.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2019.csv') as f:
    nRows = 0
    dfchunks = []
    for dfchunk in pd.read_csv(f,sep=';',encoding='ISO-8859-1',usecols=columns,dtype=dtype,chunksize=500000):
      nRows = nRows + len(dfchunk)
      print('processed {0}'.format(nRows))
      dfchunks.append(dfchunk)

df = pd.concat(dfchunks)
# Out:
# processed 500000
# processed 1000000
# processed 1500000
# processed 2000000
# processed 2500000
# processed 3000000
# processed 3500000
# processed 4000000
# processed 4500000
# processed 5000000
# processed 5095171
# CPU times: user 1min 1s, sys: 2.25 s, total: 1min 3s
# Wall time: 1min 5s

# %%
df.head()
# Out:
#    NU_INSCRICAO NU_ANO TP_FAIXA_ETARIA TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA  \
# 0  190001595656   2019              13       M               1           3
# 1  190001421546   2019               8       M               1           1
# 2  190001133210   2019              13       F               1           3
# 3  190001199383   2019              10       F               1           1
# 4  190001237802   2019               7       F               1           1
#
#   TP_ST_CONCLUSAO TP_ANO_CONCLUIU TP_ESCOLA TP_ENSINO  ... Q016  Q017 Q018  \
# 0               1              11         1       NaN  ...    A     A    A
# 1               1               5         1         1  ...    A     A    A
# 2               1              13         1         1  ...    A     A    A
# 3               1               4         1       NaN  ...    A     A    A
# 4               1               4         1         1  ...    B     A    A
#
#   Q019 Q020  Q021 Q022 Q023  Q024  Q025
# 0    A    A     A    C    A     C     B
# 1    B    A     A    E    A     A     B
# 2    B    A     A    C    A     A     B
# 3    C    A     B    D    A     B     B
# 4    B    A     A    C    B     B     B
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (5095171, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5095171 entries, 0 to 5095170
# Data columns (total 49 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   NU_INSCRICAO        int64
#  1   NU_ANO              category
#  2   TP_FAIXA_ETARIA     category
#  3   TP_SEXO             category
#  4   TP_ESTADO_CIVIL     object
#  5   TP_COR_RACA         category
#  6   TP_ST_CONCLUSAO     category
#  7   TP_ANO_CONCLUIU     category
#  8   TP_ESCOLA           category
#  9   TP_ENSINO           object
#  10  IN_TREINEIRO        category
#  11  CO_MUNICIPIO_ESC    float64
#  12  NO_MUNICIPIO_ESC    object
#  13  SG_UF_ESC           object
#  14  TP_LOCALIZACAO_ESC  object
#  15  CO_MUNICIPIO_PROVA  float64
#  16  NO_MUNICIPIO_PROVA  object
#  17  SG_UF_PROVA         object
#  18  NU_NOTA_CN          float64
#  19  NU_NOTA_CH          float64
#  20  NU_NOTA_LC          float64
#  21  NU_NOTA_MT          float64
#  22  TP_LINGUA           category
#  23  NU_NOTA_REDACAO     float64
#  24  Q001                category
#  25  Q002                category
#  26  Q003                category
#  27  Q004                category
#  28  Q005                float64
#  29  Q006                category
#  30  Q007                category
#  31  Q008                category
#  32  Q009                category
#  33  Q010                category
#  34  Q011                category
#  35  Q012                category
#  36  Q013                category
#  37  Q014                category
#  38  Q015                category
#  39  Q016                category
#  40  Q017                category
#  41  Q018                category
#  42  Q019                category
#  43  Q020                category
#  44  Q021                category
#  45  Q022                category
#  46  Q023                category
#  47  Q024                category
#  48  Q025                category
# dtypes: category(33), float64(8), int64(1), object(7)
# memory usage: 782.3+ MB

# %% [markdown]
# **Validação**

# %%
tb_desc = df.describe(include='all')
tb_desc.to_excel('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Desc_1_2019.xlsx')

# %% [markdown]
# # **Critérios de Inclusão/Exclusão**

# %%
tb1 = df[['IN_TREINEIRO','NU_ANO']].groupby('IN_TREINEIRO').count()
display(tb1)
# Out:
#                NU_ANO
# IN_TREINEIRO
# 0             4478504
# 1              616667

# %%
tb2 = df[['TP_ST_CONCLUSAO','NU_ANO']].groupby('TP_ST_CONCLUSAO').count()
display(tb2)
# Out:
#                   NU_ANO
# TP_ST_CONCLUSAO
# 1                2992857
# 2                1465862
# 3                 616667
# 4                  19785

# %%
tb3 = pd.crosstab(df.IN_TREINEIRO,df.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb3)
# Out:
# TP_ST_CONCLUSAO        1        2       3      4      All
# IN_TREINEIRO
# 0                2992857  1465862       0  19785  4478504
# 1                      0        0  616667      0   616667
# All              2992857  1465862  616667  19785  5095171

# %% [markdown]
# - IN_TREINEIRO: Treineiro

# %%
df_f = df.loc[df['IN_TREINEIRO'] == '0']
df_f.shape
# Out:
# (4478504, 49)

# %% [markdown]
# - TP_ST_CONCLUSAO: situação da conclusão do Ensino Médio

# %%
df_f = df_f.loc[(df_f['TP_ST_CONCLUSAO'] != '3') & (df_f['TP_ST_CONCLUSAO'] != '4')]
df_f.shape
# Out:
# (4458719, 49)

# %% [markdown]
# # **Análise de Dados Missings**

# %% [markdown]
# - Verificação

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO                0
# NU_ANO                      0
# TP_FAIXA_ETARIA             0
# TP_SEXO                     0
# TP_ESTADO_CIVIL             0
# TP_COR_RACA                 0
# TP_ST_CONCLUSAO             0
# TP_ANO_CONCLUIU             0
# TP_ESCOLA                   0
# TP_ENSINO             1580584
# IN_TREINEIRO                0
# CO_MUNICIPIO_ESC      3311332
# NO_MUNICIPIO_ESC      3311332
# SG_UF_ESC             3311332
# TP_LOCALIZACAO_ESC    3311332
# CO_MUNICIPIO_PROVA          0
# NO_MUNICIPIO_PROVA          0
# SG_UF_PROVA                 0
# NU_NOTA_CN            1289534
# NU_NOTA_CH            1111257
# NU_NOTA_LC            1111257
# NU_NOTA_MT            1289534
# TP_LINGUA                   0
# NU_NOTA_REDACAO       1111258
# Q001                        0
# Q002                        0
# Q003                        0
# Q004                        0
# Q005                        0
# Q006                        0
# Q007                        0
# Q008                        0
# Q009                        0
# Q010                        0
# Q011                        0
# Q012                        0
# Q013                        0
# Q014                        0
# Q015                        0
# Q016                        0
# Q017                        0
# Q018                        0
# Q019                        0
# Q020                        0
# Q021                        0
# Q022                        0
# Q023                        0
# Q024                        0
# Q025                        0
# dtype: int64

# %% [markdown]
# - Inclusão da categoria Missing apenas nos Inputs

# %% [markdown]
# - Tipo de Ensino

# %%
df_f['TP_ENSINO'].fillna('9', inplace=True)

# %%
df_f[['TP_ENSINO','NU_ANO']].groupby('TP_ENSINO').count()
# Out:
#             NU_ANO
# TP_ENSINO
# 1          2864336
# 2            13799
# 9          1580584

# %%
df_f[['TP_ENSINO','NU_ANO']].groupby('TP_ENSINO').count().sum()
# Out:
# NU_ANO    4458719
# dtype: int64

# %% [markdown]
# - Variáveis relacionadas à Escola

# %%
df_f['CO_MUNICIPIO_ESC'].fillna('-1', inplace=True)
df_f['NO_MUNICIPIO_ESC'].fillna('-1', inplace=True)
df_f['SG_UF_ESC'].fillna('-1', inplace=True)
df_f['TP_LOCALIZACAO_ESC'].fillna('-1', inplace=True)

# %%
df_f[['CO_MUNICIPIO_ESC','NU_ANO']].groupby('CO_MUNICIPIO_ESC').count()
# Out:
#                    NU_ANO
# CO_MUNICIPIO_ESC
# 1100015.0             158
# 1100023.0             716
# 1100031.0              24
# 1100049.0             926
# 1100056.0              99
# ...                   ...
# 5222054.0              28
# 5222203.0              18
# 5222302.0              15
# 5300108.0           21075
# -1                3311332
#
# [5545 rows x 1 columns]

# %%
df_f[['NO_MUNICIPIO_ESC','NU_ANO']].groupby('NO_MUNICIPIO_ESC').count()
# Out:
#                       NU_ANO
# NO_MUNICIPIO_ESC
# -1                   3311332
# Abadia de Goiás           79
# Abadia dos Dourados       18
# Abadiânia                102
# Abaetetuba              1121
# ...                      ...
# Áurea                     15
# Ângulo                    12
# Érico Cardoso             37
# Óbidos                   226
# Óleo                      29
#
# [5278 rows x 1 columns]

# %%
df_f[['SG_UF_ESC','NU_ANO']].groupby('SG_UF_ESC').count()
# Out:
#             NU_ANO
# SG_UF_ESC
# -1         3311332
# AC            5330
# AL           17551
# AM           25817
# AP            6135
# BA           70323
# CE          112313
# DF           21075
# ES           25422
# GO           35545
# MA           43496
# MG          108173
# MS           15539
# MT           18022
# PA           46740
# PB           26938
# PE           61506
# PI           24145
# PR           52788
# RJ           73085
# RN           20349
# RO           12069
# RR            2202
# RS           46173
# SC           34646
# SE           13494
# SP          219424
# TO            9087

# %%
df_f[['TP_LOCALIZACAO_ESC','NU_ANO']].groupby('TP_LOCALIZACAO_ESC').count()
# Out:
#                      NU_ANO
# TP_LOCALIZACAO_ESC
# -1                  3311332
# 1                   1105846
# 2                     41541

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO                0
# NU_ANO                      0
# TP_FAIXA_ETARIA             0
# TP_SEXO                     0
# TP_ESTADO_CIVIL             0
# TP_COR_RACA                 0
# TP_ST_CONCLUSAO             0
# TP_ANO_CONCLUIU             0
# TP_ESCOLA                   0
# TP_ENSINO                   0
# IN_TREINEIRO                0
# CO_MUNICIPIO_ESC            0
# NO_MUNICIPIO_ESC            0
# SG_UF_ESC                   0
# TP_LOCALIZACAO_ESC          0
# CO_MUNICIPIO_PROVA          0
# NO_MUNICIPIO_PROVA          0
# SG_UF_PROVA                 0
# NU_NOTA_CN            1289534
# NU_NOTA_CH            1111257
# NU_NOTA_LC            1111257
# NU_NOTA_MT            1289534
# TP_LINGUA                   0
# NU_NOTA_REDACAO       1111258
# Q001                        0
# Q002                        0
# Q003                        0
# Q004                        0
# Q005                        0
# Q006                        0
# Q007                        0
# Q008                        0
# Q009                        0
# Q010                        0
# Q011                        0
# Q012                        0
# Q013                        0
# Q014                        0
# Q015                        0
# Q016                        0
# Q017                        0
# Q018                        0
# Q019                        0
# Q020                        0
# Q021                        0
# Q022                        0
# Q023                        0
# Q024                        0
# Q025                        0
# dtype: int64

# %% [markdown]
# - Exclusão de informações missings no Target

# %%
df_f.dropna(subset=['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'], inplace=True, axis=0) # Axis = 0 exclui as linhas, =1, as colunas

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO          0
# NU_ANO                0
# TP_FAIXA_ETARIA       0
# TP_SEXO               0
# TP_ESTADO_CIVIL       0
# TP_COR_RACA           0
# TP_ST_CONCLUSAO       0
# TP_ANO_CONCLUIU       0
# TP_ESCOLA             0
# TP_ENSINO             0
# IN_TREINEIRO          0
# CO_MUNICIPIO_ESC      0
# NO_MUNICIPIO_ESC      0
# SG_UF_ESC             0
# TP_LOCALIZACAO_ESC    0
# CO_MUNICIPIO_PROVA    0
# NO_MUNICIPIO_PROVA    0
# SG_UF_PROVA           0
# NU_NOTA_CN            0
# NU_NOTA_CH            0
# NU_NOTA_LC            0
# NU_NOTA_MT            0
# TP_LINGUA             0
# NU_NOTA_REDACAO       0
# Q001                  0
# Q002                  0
# Q003                  0
# Q004                  0
# Q005                  0
# Q006                  0
# Q007                  0
# Q008                  0
# Q009                  0
# Q010                  0
# Q011                  0
# Q012                  0
# Q013                  0
# Q014                  0
# Q015                  0
# Q016                  0
# Q017                  0
# Q018                  0
# Q019                  0
# Q020                  0
# Q021                  0
# Q022                  0
# Q023                  0
# Q024                  0
# Q025                  0
# dtype: int64

# %%
df_f.shape
# Out:
# (3163713, 49)

# %% [markdown]
# # **Padronização das Variáveis**

# %% [markdown]
# - Estado Civil

# %%
df_f.TP_ESTADO_CIVIL.value_counts()
# Out:
# 1    2777776
# 2     220287
# 0     112921
# 3      49103
# 4       3626
# Name: TP_ESTADO_CIVIL, dtype: int64

# %% [markdown]
# - TP_ESCOLA

# %%
df_f.TP_ESCOLA.value_counts()
# Out:
# 1    1946592
# 2    1009824
# 3     207297
# Name: TP_ESCOLA, dtype: int64

# %% [markdown]
# # **Análise Descritiva**

# %% [markdown]
# - **Variáveis Quantitiativas**

# %%
round(df_f.describe(include=None),1)
# Out:
#        NU_INSCRICAO  CO_MUNICIPIO_PROVA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# count  3.163713e+06           3163713.0   3163713.0   3163713.0   3163713.0
# mean   1.900034e+11           3066768.2       477.1       509.6       521.9
# std    1.446774e+06            987958.5        76.2        81.3        62.9
# min    1.900010e+11           1100015.0         0.0         0.0         0.0
# 25%    1.900022e+11           2402600.0       417.2       450.2       484.8
# 50%    1.900033e+11           3115508.0       468.8       512.5       526.8
# 75%    1.900046e+11           3548500.0       531.4       568.1       565.9
# max    1.900061e+11           5300108.0       860.9       835.1       801.7
#
#        NU_NOTA_MT  NU_NOTA_REDACAO       Q005
# count   3163713.0        3163713.0  3163713.0
# mean        520.8            580.5        3.9
# std         109.3            181.6        1.5
# min           0.0              0.0        1.0
# 25%         433.1            500.0        3.0
# 50%         497.4            580.0        4.0
# 75%         594.1            680.0        5.0
# max         985.5           1000.0       20.0

# %% [markdown]
# - **Variáveis Qualitativas**

# %%
df_f.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU',
#        'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_LOCALIZACAO_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN',
#        'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015',
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object')

# %%
df_varquali = df_f[['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO',
             'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', #'NO_MUNICIPIO_ESC', 'NO_MUNICIPIO_PROVA',
             'SG_UF_ESC', 'TP_LOCALIZACAO_ESC', 'SG_UF_PROVA', 'TP_LINGUA',
             'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012',
             'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023',
             'Q024', 'Q025']]

# %%
dist_freq_quali = pd.DataFrame()
dist_freq_quali_t = list()

for column in df_varquali:
  freq_var = df_varquali[column].value_counts().sort_index()
  perc_var = df_varquali[column].value_counts(normalize=True).sort_index() * 100
  dist_freq_quali_ = pd.DataFrame({'n': freq_var,
                                   '(%)': perc_var})
  dist_freq_quali_t_ = dist_freq_quali_['n'].sum()

  dist_freq_quali = pd.concat([dist_freq_quali, dist_freq_quali_])
  dist_freq_quali_t.append(dist_freq_quali_t_)

dist_freq_quali.to_excel('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Desc_2_2019.xlsx')

# %% [markdown]
# # **Análise Gráfica (Target)**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# > **Boxplot**

# %%
labels = ['','CN','CH','LC','MT','Redação']

df_f.boxplot(column = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'],
             showmeans=True)
plt.xlabel('Competência')
plt.xticks(range(len(labels)),labels, rotation=0)
plt.ylabel('Nota')
plt.title('2019')
plt.xlim()
plt.grid()
plt.savefig('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Notas_2019.png')
plt.show()

# %%
selcol = df_f[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']]

# %%
sns.set_theme(style="ticks")
sns.pairplot(selcol)

# %% [markdown]
# # **Análise de Correlação**

# %% [markdown]
# - Entre as variáveis respostas

# %%
corr1 = selcol.corr(method='pearson')
print(corr1)
corr2 = selcol.corr(method='spearman')
print(corr2)

plt.imshow(corr2, cmap='hot', interpolation='none')
plt.colorbar()
plt.title('2019')
plt.xticks(range(len(corr2)), rotation=90, labels=['CN','CH','LC','MT','Redação'])
plt.yticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação']);
plt.savefig("Notas_2019 - Matriz de Correlacao (S).png")
plt.show()
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_NOTA_CN         1.000000    0.671898    0.644174    0.650153
# NU_NOTA_CH         0.671898    1.000000    0.746410    0.612976
# NU_NOTA_LC         0.644174    0.746410    1.000000    0.590929
# NU_NOTA_MT         0.650153    0.612976    0.590929    1.000000
# NU_NOTA_REDACAO    0.511146    0.536066    0.546593    0.503167
#
#                  NU_NOTA_REDACAO
# NU_NOTA_CN              0.511146
# NU_NOTA_CH              0.536066
# NU_NOTA_LC              0.546593
# NU_NOTA_MT              0.503167
# NU_NOTA_REDACAO         1.000000
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_NOTA_CN         1.000000    0.663346    0.664126    0.577111
# NU_NOTA_CH         0.663346    1.000000    0.773434    0.583445
# NU_NOTA_LC         0.664126    0.773434    1.000000    0.595771
# NU_NOTA_MT         0.577111    0.583445    0.595771    1.000000
# NU_NOTA_REDACAO    0.513990    0.559675    0.574790    0.497407
#
#                  NU_NOTA_REDACAO
# NU_NOTA_CN              0.513990
# NU_NOTA_CH              0.559675
# NU_NOTA_LC              0.574790
# NU_NOTA_MT              0.497407
# NU_NOTA_REDACAO         1.000000

# %%
plt.figure(figsize=(15,8))
matriz = np.triu(corr2)
sns.heatmap(corr2, mask= matriz, annot=True, cmap='YlGnBu')
plt.title('2019')
plt.xticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação'])
plt.yticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação']);
plt.savefig("/content/drive/MyDrive/MBA_TCC/RESULTADOS/Notas_2019 - Matriz de Correlacao (S).png")
plt.show()

# %% [markdown]
# # **Validações**

# %%
tb4 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ENSINO, margins=True, dropna=False)
display(tb4)
# Out:
# TP_ENSINO        1     2        9      All
# SG_UF_ESC
# -1         1204440  6469   998917  2209826
# AC            4324    11      251     4586
# AL           13738    48     1138    14924
# AM           19194    42      930    20166
# AP            4697    17      490     5204
# BA           55860   259     3442    59561
# CE           85599    83     2607    88289
# DF           17475    24     1169    18668
# ES           20261    31     1487    21779
# GO           28299   113     2097    30509
# MA           34879    53     1499    36431
# MG           86925   272     4615    91812
# MS           12342    36      783    13161
# MT           14261    32      714    15007
# PA           37463   193     2602    40258
# PB           21848    59     1577    23484
# PE           48808   154     2298    51260
# PI           19804    80     1355    21239
# PR           41151   117     1208    42476
# RJ           58482   172     3155    61809
# RN           16714    64     1182    17960
# RO            8655    27     1072     9754
# RR            1655     4       92     1751
# RS           36968    71     2016    39055
# SC           27655    37      539    28231
# SE           11332    15      392    11739
# SP          171117   310     5612   177039
# TO            7321    19      395     7735
# All        2111267  8812  1043634  3163713

# %%
tb5 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ANO_CONCLUIU, margins=True, dropna=False)
display(tb5)
# Out:
# TP_ANO_CONCLUIU        0       1     10     11     12      13       2       3  \
# SG_UF_ESC
# -1                326406  489373  43843  35952  33149  233131  312428  206454
# AC                  4586       0      0      0      0       0       0       0
# AL                 14924       0      0      0      0       0       0       0
# AM                 20166       0      0      0      0       0       0       0
# AP                  5204       0      0      0      0       0       0       0
# BA                 59561       0      0      0      0       0       0       0
# CE                 88289       0      0      0      0       0       0       0
# DF                 18668       0      0      0      0       0       0       0
# ES                 21779       0      0      0      0       0       0       0
# GO                 30509       0      0      0      0       0       0       0
# MA                 36431       0      0      0      0       0       0       0
# MG                 91812       0      0      0      0       0       0       0
# MS                 13161       0      0      0      0       0       0       0
# MT                 15007       0      0      0      0       0       0       0
# PA                 40258       0      0      0      0       0       0       0
# PB                 23484       0      0      0      0       0       0       0
# PE                 51260       0      0      0      0       0       0       0
# PI                 21239       0      0      0      0       0       0       0
# PR                 42476       0      0      0      0       0       0       0
# RJ                 61809       0      0      0      0       0       0       0
# RN                 17960       0      0      0      0       0       0       0
# RO                  9754       0      0      0      0       0       0       0
# RR                  1751       0      0      0      0       0       0       0
# RS                 39055       0      0      0      0       0       0       0
# SC                 28231       0      0      0      0       0       0       0
# SE                 11739       0      0      0      0       0       0       0
# SP                177039       0      0      0      0       0       0       0
# TO                  7735       0      0      0      0       0       0       0
# All              1280293  489373  43843  35952  33149  233131  312428  206454
#
# TP_ANO_CONCLUIU       4       5      6      7      8      9      All
# SG_UF_ESC
# -1               149510  113914  87304  72264  55862  50236  2209826
# AC                    0       0      0      0      0      0     4586
# AL                    0       0      0      0      0      0    14924
# AM                    0       0      0      0      0      0    20166
# AP                    0       0      0      0      0      0     5204
# BA                    0       0      0      0      0      0    59561
# CE                    0       0      0      0      0      0    88289
# DF                    0       0      0      0      0      0    18668
# ES                    0       0      0      0      0      0    21779
# GO                    0       0      0      0      0      0    30509
# MA                    0       0      0      0      0      0    36431
# MG                    0       0      0      0      0      0    91812
# MS                    0       0      0      0      0      0    13161
# MT                    0       0      0      0      0      0    15007
# PA                    0       0      0      0      0      0    40258
# PB                    0       0      0      0      0      0    23484
# PE                    0       0      0      0      0      0    51260
# PI                    0       0      0      0      0      0    21239
# PR                    0       0      0      0      0      0    42476
# RJ                    0       0      0      0      0      0    61809
# RN                    0       0      0      0      0      0    17960
# RO                    0       0      0      0      0      0     9754
# RR                    0       0      0      0      0      0     1751
# RS                    0       0      0      0      0      0    39055
# SC                    0       0      0      0      0      0    28231
# SE                    0       0      0      0      0      0    11739
# SP                    0       0      0      0      0      0   177039
# TO                    0       0      0      0      0      0     7735
# All              149510  113914  87304  72264  55862  50236  3163713

# %%
tb6 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb6)
# Out:
# TP_ST_CONCLUSAO        1        2  3  4      All
# SG_UF_ESC
# -1               1946591   263235  0  0  2209826
# AC                     0     4586  0  0     4586
# AL                     0    14924  0  0    14924
# AM                     0    20166  0  0    20166
# AP                     0     5204  0  0     5204
# BA                     0    59561  0  0    59561
# CE                     0    88289  0  0    88289
# DF                     0    18668  0  0    18668
# ES                     0    21779  0  0    21779
# GO                     0    30509  0  0    30509
# MA                     0    36431  0  0    36431
# MG                     0    91812  0  0    91812
# MS                     0    13161  0  0    13161
# MT                     0    15007  0  0    15007
# PA                     0    40258  0  0    40258
# PB                     0    23484  0  0    23484
# PE                     0    51260  0  0    51260
# PI                     0    21239  0  0    21239
# PR                     0    42476  0  0    42476
# RJ                     0    61809  0  0    61809
# RN                     0    17960  0  0    17960
# RO                     0     9754  0  0     9754
# RR                     0     1751  0  0     1751
# RS                     0    39055  0  0    39055
# SC                     0    28231  0  0    28231
# SE                     0    11739  0  0    11739
# SP                     0   177039  0  0   177039
# TO                     0     7735  0  0     7735
# All              1946591  1217122  0  0  3163713

# %%
tb7 = pd.crosstab(df_f.TP_ESCOLA,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb7)
# Out:
# TP_ST_CONCLUSAO        1        2  3  4      All
# TP_ESCOLA
# 1                1946591        1  0  0  1946592
# 2                      0  1009824  0  0  1009824
# 3                      0   207297  0  0   207297
# All              1946591  1217122  0  0  3163713

# %% [markdown]
# # **Exclusão de Colunas**

# %%
df_f.drop(['IN_TREINEIRO'], axis = 1, inplace = True)
df_f.shape
# Out:
# (3163713, 48)

# %% [markdown]
# # **Verificação de Duplicidade na Base Final**

# %%
df_f.NU_INSCRICAO.unique()
# Out:
# array([190001199383, 190001237802, 190001782198, ..., 190005863627,
#        190005771624, 190005865726])

# %%
df_f.shape
# Out:
# (3163713, 48)

# %% [markdown]
# # **Exportar base final**

# %%
df_f.to_csv('/content/drive/MyDrive/MBA_TCC/DADOS/df_f_2019.csv', index=False)

# %%
#selcol.to_csv('/content/drive/MyDrive/MBA_TCC/DADOS/notas_2018.csv', index=False)

# %% [markdown]
# # **Importar bases**

# %%
df_f = pd.read_csv('/content/drive/MyDrive/MBA_TCC/DADOS/df_f_2019.csv',sep=',',encoding='ISO-8859-1')
df_f.shape

# %%
df_f.info()

# %% [markdown]
# # **Separação Input/Target**

# %%
y = dadosv['style']
x = dadosv.drop('style', axis = 1)

# %% [markdown]
# # **Train/Test**

# %%
# BIBLIOTECA SCIKIT LEARN

from sklearn.model_selection import train_test_split


# Dados de Treino/Teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.3)
print(x_treino.shape)
print(x_teste.shape)
print(y_treino.shape)
print(y_teste.shape)
