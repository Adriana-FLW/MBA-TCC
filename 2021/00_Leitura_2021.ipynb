# %% [markdown]
# <a href="https://colab.research.google.com/github/Adriana-FLW/MBA_TCC/blob/main/00_Leitura_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ENEM 2021**

# %% [markdown]
# # Biblioteca

# %%
import pandas as pd
import zipfile

# %% [markdown]
# # Importar Dados

# %% [markdown]
# - **Localizar microdados**

# %%
with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2021.zip') as z:
  print(*z.namelist(),sep='\n')
# Out:
# INPUTS/
# INPUTS/INPUT_R_ITENS_PROVA_2021.R
# INPUTS/INPUT_R_MICRODADOS_ENEM_2021.R
# INPUTS/INPUT_SAS_ITENS_PROVA_2021.sas
# INPUTS/INPUT_SAS_MICRODADOS_ENEM_2021.sas
# INPUTS/INPUT_SPSS_ITENS_PROVA_2021.sps
# INPUTS/INPUT_SPSS_MICRODADOS_ENEM_2021.sps
# LEIA-ME E DOCUMENTOS TÉCNICOS/
# LEIA-ME E DOCUMENTOS TÉCNICOS/Edital_Enem_2021_Digital.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/Edital_Enem_2021_Impresso.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/enem_procedimentos_de_analise.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/entenda_a_sua_nota_no_enem_guia_do_participante (2).pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/Leia_Me_Enem_2021.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/manual_de_redacao_do_enem_2020.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/matriz_referencia_enem.pdf
# PROVAS E GABARITOS/
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_01_DIA_1_AZUL_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_01_DIA_1_AZUL_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_02_DIA_1_AMARELO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_02_DIA_1_AMARELO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_03_DIA_1_BRANCO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_03_DIA_1_BRANCO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_04_DIA_1_ROSA_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_04_DIA_1_ROSA_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_01_DIA_1_AZUL_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_01_DIA_1_AZUL_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_02_DIA_1_AMARELO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_02_DIA_1_AMARELO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_03_DIA_1_BRANCO_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_03_DIA_1_BRANCO_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_04_DIA_1_ROSA_ESPANHOL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_04_DIA_1_ROSA_INGLES.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_DIGITAL_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_02_DIA_1_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_02_DIA_1_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_05_DIA_2_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_05_DIA_2_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_10_DIA_1_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_10_DIA_1_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_12_DIA_2_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_12_DIA_2_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_CAD_12_DIA_2_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_02_DIA_1_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_02_DIA_1_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_05_DIA_2_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_05_DIA_2_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_10_DIA_1_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_10_DIA_1_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_12_DIA_2_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_12_DIA_2_VERDE_LIBRAS_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P1_GAB_12_DIA_2_VERDE_LIBRAS_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_02_DIA_1_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_02_DIA_1_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_05_DIA_2_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_05_DIA_2_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_CAD_11_DIA_2_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_02_DIA_1_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_02_DIA_1_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_04_DIA_1_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_05_DIA_2_AMARELO_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_05_DIA_2_AMARELO_SUPERAMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_06_DIA_2_CINZA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_07_DIA_2_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_08_DIA_2_ROSA.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2021_P2_GAB_11_DIA_2_LARANJA_LEDOR.pdf
# DADOS/
# DADOS/ITENS_PROVA_2021.csv
# DADOS/MICRODADOS_ENEM_2021.csv
# DICION╡RIO/
# DICION╡RIO/Dicionário_Microdados_Enem_2021.ods
# DICION╡RIO/Dicionário_Microdados_Enem_2021.xlsx

# %% [markdown]
# - **Identificaçáo das colunas**

# %%
with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2021.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2021.csv') as f:
    df = pd.read_csv(f,sep=';',encoding='ISO-8859-1',nrows=5)

# %%
df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            5 non-null      int64
#  1   NU_ANO                  5 non-null      int64
#  2   TP_FAIXA_ETARIA         5 non-null      int64
#  3   TP_SEXO                 5 non-null      object
#  4   TP_ESTADO_CIVIL         5 non-null      int64
#  5   TP_COR_RACA             5 non-null      int64
#  6   TP_NACIONALIDADE        5 non-null      int64
#  7   TP_ST_CONCLUSAO         5 non-null      int64
#  8   TP_ANO_CONCLUIU         5 non-null      int64
#  9   TP_ESCOLA               5 non-null      int64
#  10  TP_ENSINO               2 non-null      float64
#  11  IN_TREINEIRO            5 non-null      int64
#  12  CO_MUNICIPIO_ESC        2 non-null      float64
#  13  NO_MUNICIPIO_ESC        2 non-null      object
#  14  CO_UF_ESC               2 non-null      float64
#  15  SG_UF_ESC               2 non-null      object
#  16  TP_DEPENDENCIA_ADM_ESC  2 non-null      float64
#  17  TP_LOCALIZACAO_ESC      2 non-null      float64
#  18  TP_SIT_FUNC_ESC         2 non-null      float64
#  19  CO_MUNICIPIO_PROVA      5 non-null      int64
#  20  NO_MUNICIPIO_PROVA      5 non-null      object
#  21  CO_UF_PROVA             5 non-null      int64
#  22  SG_UF_PROVA             5 non-null      object
#  23  TP_PRESENCA_CN          5 non-null      int64
#  24  TP_PRESENCA_CH          5 non-null      int64
#  25  TP_PRESENCA_LC          5 non-null      int64
#  26  TP_PRESENCA_MT          5 non-null      int64
#  27  CO_PROVA_CN             3 non-null      float64
#  28  CO_PROVA_CH             4 non-null      float64
#  29  CO_PROVA_LC             4 non-null      float64
#  30  CO_PROVA_MT             3 non-null      float64
#  31  NU_NOTA_CN              3 non-null      float64
#  32  NU_NOTA_CH              4 non-null      float64
#  33  NU_NOTA_LC              4 non-null      float64
#  34  NU_NOTA_MT              3 non-null      float64
#  35  TX_RESPOSTAS_CN         3 non-null      object
#  36  TX_RESPOSTAS_CH         4 non-null      object
#  37  TX_RESPOSTAS_LC         4 non-null      object
#  38  TX_RESPOSTAS_MT         3 non-null      object
#  39  TP_LINGUA               5 non-null      int64
#  40  TX_GABARITO_CN          3 non-null      object
#  41  TX_GABARITO_CH          4 non-null      object
#  42  TX_GABARITO_LC          4 non-null      object
#  43  TX_GABARITO_MT          3 non-null      object
#  44  TP_STATUS_REDACAO       4 non-null      float64
#  45  NU_NOTA_COMP1           4 non-null      float64
#  46  NU_NOTA_COMP2           4 non-null      float64
#  47  NU_NOTA_COMP3           4 non-null      float64
#  48  NU_NOTA_COMP4           4 non-null      float64
#  49  NU_NOTA_COMP5           4 non-null      float64
#  50  NU_NOTA_REDACAO         4 non-null      float64
#  51  Q001                    5 non-null      object
#  52  Q002                    5 non-null      object
#  53  Q003                    5 non-null      object
#  54  Q004                    5 non-null      object
#  55  Q005                    5 non-null      int64
#  56  Q006                    5 non-null      object
#  57  Q007                    5 non-null      object
#  58  Q008                    5 non-null      object
#  59  Q009                    5 non-null      object
#  60  Q010                    5 non-null      object
#  61  Q011                    5 non-null      object
#  62  Q012                    5 non-null      object
#  63  Q013                    5 non-null      object
#  64  Q014                    5 non-null      object
#  65  Q015                    5 non-null      object
#  66  Q016                    5 non-null      object
#  67  Q017                    5 non-null      object
#  68  Q018                    5 non-null      object
#  69  Q019                    5 non-null      object
#  70  Q020                    5 non-null      object
#  71  Q021                    5 non-null      object
#  72  Q022                    5 non-null      object
#  73  Q023                    5 non-null      object
#  74  Q024                    5 non-null      object
#  75  Q025                    5 non-null      object
# dtypes: float64(21), int64(18), object(37)
# memory usage: 3.1+ KB

# %%
df[['CO_MUNICIPIO_ESC','SG_UF_ESC','CO_UF_ESC','NO_MUNICIPIO_ESC']]
# Out:
#    CO_MUNICIPIO_ESC SG_UF_ESC  CO_UF_ESC NO_MUNICIPIO_ESC
# 0               NaN       NaN        NaN              NaN
# 1               NaN       NaN        NaN              NaN
# 2               NaN       NaN        NaN              NaN
# 3         2304202.0        CE       23.0            Crato
# 4         2311603.0        CE       23.0         Redenção

# %%
colunas = [
'NU_INSCRICAO',
'NU_ANO',
'TP_FAIXA_ETARIA',
'TP_SEXO',
'TP_ESTADO_CIVIL',
'TP_COR_RACA',
'TP_ST_CONCLUSAO',
'TP_ANO_CONCLUIU',
'TP_ESCOLA',
'TP_ENSINO',
'IN_TREINEIRO',
'CO_MUNICIPIO_ESC',
'NO_MUNICIPIO_ESC',
'SG_UF_ESC',
'TP_LOCALIZACAO_ESC',
'CO_MUNICIPIO_PROVA',
'NO_MUNICIPIO_PROVA',
'SG_UF_PROVA',
'NU_NOTA_CN',
'NU_NOTA_CH',
'NU_NOTA_LC',
'NU_NOTA_MT',
'TP_LINGUA',
'NU_NOTA_REDACAO',
'Q001',
'Q002',
'Q003',
'Q004',
'Q005',
'Q006',
'Q007',
'Q008',
'Q009',
'Q010',
'Q011',
'Q012',
'Q013',
'Q014',
'Q015',
'Q016',
'Q017',
'Q018',
'Q019',
'Q020',
'Q021',
'Q022',
'Q023',
'Q024',
'Q025']

# %%
dtype = {
'NU_INSCRICAO':'int64',
'NU_ANO':'category',
'TP_FAIXA_ETARIA':'category',
'TP_SEXO':'category',
'TP_ESTADO_CIVIL':'object',
'TP_COR_RACA':'category',
'TP_ST_CONCLUSAO':'category',
'TP_ANO_CONCLUIU':'category',
'TP_ESCOLA':'category',
'TP_ENSINO':'object',
'IN_TREINEIRO':'category',
'CO_MUNICIPIO_ESC':'float64',
'NO_MUNICIPIO_ESC':'object',
'SG_UF_ESC':'object',
'TP_LOCALIZACAO_ESC':'object',
'CO_MUNICIPIO_PROVA':'float64',
'NO_MUNICIPIO_PROVA':'object',
'SG_UF_PROVA':'object',
'NU_NOTA_CN':'float64',
'NU_NOTA_CH':'float64',
'NU_NOTA_LC':'float64',
'NU_NOTA_MT':'float64',
'TP_LINGUA':'category',
'NU_NOTA_REDACAO':'float64',
'Q001':'category',
'Q002':'category',
'Q003':'category',
'Q004':'category',
'Q005':'float64',
'Q006':'category',
'Q007':'category',
'Q008':'category',
'Q009':'category',
'Q010':'category',
'Q011':'category',
'Q012':'category',
'Q013':'category',
'Q014':'category',
'Q015':'category',
'Q016':'category',
'Q017':'category',
'Q018':'category',
'Q019':'category',
'Q020':'category',
'Q021':'category',
'Q022':'category',
'Q023':'category',
'Q024':'category',
'Q025':'category'}

# %%
columns = list(dtype.keys())
dtype.keys()
# Out:
# dict_keys(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_LOCALIZACAO_ESC', 'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'])

# %% [markdown]
# - **Importar arquivo (apenas as colunas necessárias)**

# %%
# %%time

with zipfile.ZipFile('/content/drive/MyDrive/MBA_TCC/DADOS/microdados_enem_2021.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2021.csv') as f:
    nRows = 0
    dfchunks = []
    for dfchunk in pd.read_csv(f,sep=';',encoding='ISO-8859-1',usecols=columns,dtype=dtype,chunksize=500000):
      nRows = nRows + len(dfchunk)
      print('processed {0}'.format(nRows))
      dfchunks.append(dfchunk)

df = pd.concat(dfchunks)
# Out:
# processed 500000
# processed 1000000
# processed 1500000
# processed 2000000
# processed 2500000
# processed 3000000
# processed 3389832
# CPU times: user 39.4 s, sys: 1.5 s, total: 40.9 s
# Wall time: 42.3 s

# %%
df.head()
# Out:
#    NU_INSCRICAO NU_ANO TP_FAIXA_ETARIA TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA  \
# 0  210053865474   2021               5       F               1           1
# 1  210052384164   2021              12       M               1           1
# 2  210052589243   2021              13       F               3           1
# 3  210052128335   2021               3       M               1           3
# 4  210051353021   2021               2       F               1           3
#
#   TP_ST_CONCLUSAO TP_ANO_CONCLUIU TP_ESCOLA TP_ENSINO  ... Q016  Q017 Q018  \
# 0               1               3         1       NaN  ...    A     A    A
# 1               1              11         1       NaN  ...    A     A    A
# 2               1              15         1       NaN  ...    B     A    A
# 3               2               0         2         1  ...    A     A    A
# 4               2               0         2         1  ...    B     A    A
#
#   Q019 Q020  Q021 Q022 Q023  Q024  Q025
# 0    B    A     A    B    A     B     B
# 1    B    A     A    C    A     A     A
# 2    B    A     A    C    B     B     B
# 3    B    A     A    B    A     B     B
# 4    B    A     B    E    A     B     B
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (3389832, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3389832 entries, 0 to 3389831
# Data columns (total 49 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   NU_INSCRICAO        int64
#  1   NU_ANO              category
#  2   TP_FAIXA_ETARIA     category
#  3   TP_SEXO             category
#  4   TP_ESTADO_CIVIL     object
#  5   TP_COR_RACA         object
#  6   TP_ST_CONCLUSAO     category
#  7   TP_ANO_CONCLUIU     category
#  8   TP_ESCOLA           category
#  9   TP_ENSINO           object
#  10  IN_TREINEIRO        category
#  11  CO_MUNICIPIO_ESC    float64
#  12  NO_MUNICIPIO_ESC    object
#  13  SG_UF_ESC           object
#  14  TP_LOCALIZACAO_ESC  object
#  15  CO_MUNICIPIO_PROVA  float64
#  16  NO_MUNICIPIO_PROVA  object
#  17  SG_UF_PROVA         object
#  18  NU_NOTA_CN          float64
#  19  NU_NOTA_CH          float64
#  20  NU_NOTA_LC          float64
#  21  NU_NOTA_MT          float64
#  22  TP_LINGUA           category
#  23  NU_NOTA_REDACAO     float64
#  24  Q001                category
#  25  Q002                category
#  26  Q003                category
#  27  Q004                category
#  28  Q005                float64
#  29  Q006                category
#  30  Q007                category
#  31  Q008                category
#  32  Q009                category
#  33  Q010                category
#  34  Q011                category
#  35  Q012                category
#  36  Q013                category
#  37  Q014                category
#  38  Q015                category
#  39  Q016                category
#  40  Q017                category
#  41  Q018                category
#  42  Q019                category
#  43  Q020                category
#  44  Q021                category
#  45  Q022                category
#  46  Q023                category
#  47  Q024                category
#  48  Q025                category
# dtypes: category(32), float64(8), int64(1), object(8)
# memory usage: 543.1+ MB

# %% [markdown]
# **Validação**

# %%
tb_desc = df.describe(include='all')
tb_desc.to_excel('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Desc_1_2021.xlsx')

# %% [markdown]
# # **Critérios de Inclusão/Exclusão**

# %%
tb1 = df[['IN_TREINEIRO','NU_ANO']].groupby('IN_TREINEIRO').count()
display(tb1)
# Out:
#                NU_ANO
# IN_TREINEIRO
# 0             2952642
# 1              437190

# %%
tb2 = df[['TP_ST_CONCLUSAO','NU_ANO']].groupby('TP_ST_CONCLUSAO').count()
display(tb2)
# Out:
#                   NU_ANO
# TP_ST_CONCLUSAO
# 1                1789372
# 2                1150857
# 3                 437190
# 4                  12413

# %%
tb3 = pd.crosstab(df.IN_TREINEIRO,df.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb3)
# Out:
# TP_ST_CONCLUSAO        1        2       3      4      All
# IN_TREINEIRO
# 0                1789372  1150857       0  12413  2952642
# 1                      0        0  437190      0   437190
# All              1789372  1150857  437190  12413  3389832

# %% [markdown]
# - IN_TREINEIRO: Treineiro

# %%
df_f = df.loc[df['IN_TREINEIRO'] == '0']
df_f.shape
# Out:
# (2952642, 49)

# %% [markdown]
# - TP_ST_CONCLUSAO: situação da conclusão do Ensino Médio

# %%
df_f = df_f.loc[(df_f['TP_ST_CONCLUSAO'] != '3') & (df_f['TP_ST_CONCLUSAO'] != '4')]
df_f.shape
# Out:
# (2940229, 49)

# %% [markdown]
# # **Análise de Dados Missings**

# %% [markdown]
# - Verificação

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO                0
# NU_ANO                      0
# TP_FAIXA_ETARIA             0
# TP_SEXO                     0
# TP_ESTADO_CIVIL             0
# TP_COR_RACA                 0
# TP_ST_CONCLUSAO             0
# TP_ANO_CONCLUIU             0
# TP_ESCOLA                   0
# TP_ENSINO             1843401
# IN_TREINEIRO                0
# CO_MUNICIPIO_ESC      2126423
# NO_MUNICIPIO_ESC      2126423
# SG_UF_ESC             2126423
# TP_LOCALIZACAO_ESC    2126423
# CO_MUNICIPIO_PROVA          0
# NO_MUNICIPIO_PROVA          0
# SG_UF_PROVA                 0
# NU_NOTA_CN            1070918
# NU_NOTA_CH             963455
# NU_NOTA_LC             963455
# NU_NOTA_MT            1070918
# TP_LINGUA                   0
# NU_NOTA_REDACAO        963455
# Q001                        2
# Q002                        2
# Q003                        2
# Q004                        2
# Q005                        2
# Q006                        2
# Q007                        2
# Q008                        2
# Q009                        2
# Q010                        2
# Q011                        2
# Q012                        2
# Q013                        2
# Q014                        2
# Q015                        2
# Q016                        2
# Q017                        2
# Q018                        2
# Q019                        2
# Q020                        2
# Q021                        2
# Q022                        2
# Q023                        2
# Q024                        2
# Q025                        2
# dtype: int64

# %% [markdown]
# - Inclusão da categoria Missing apenas nos Inputs

# %% [markdown]
# - Tipo de Ensino

# %%
df_f['TP_ENSINO'].fillna('9', inplace=True)

# %%
df_f[['TP_ENSINO','NU_ANO']].groupby('TP_ENSINO').count()
# Out:
#             NU_ANO
# TP_ENSINO
# 1          1089923
# 2             6905
# 9          1843401

# %%
df_f[['TP_ENSINO','NU_ANO']].groupby('TP_ENSINO').count().sum()
# Out:
# NU_ANO    2940229
# dtype: int64

# %% [markdown]
# - Variáveis relacionadas à Escola

# %%
df_f['CO_MUNICIPIO_ESC'].fillna('-1', inplace=True)
df_f['NO_MUNICIPIO_ESC'].fillna('-1', inplace=True)
df_f['SG_UF_ESC'].fillna('-1', inplace=True)
df_f['TP_LOCALIZACAO_ESC'].fillna('-1', inplace=True)

# %%
df_f[['CO_MUNICIPIO_ESC','NU_ANO']].groupby('CO_MUNICIPIO_ESC').count()
# Out:
#                    NU_ANO
# CO_MUNICIPIO_ESC
# 1100015.0              59
# 1100023.0             500
# 1100031.0              12
# 1100049.0             533
# 1100056.0              51
# ...                   ...
# 5222054.0             125
# 5222203.0              46
# 5222302.0              35
# 5300108.0           16913
# -1                2126423
#
# [5539 rows x 1 columns]

# %%
df_f[['NO_MUNICIPIO_ESC','NU_ANO']].groupby('NO_MUNICIPIO_ESC').count()
# Out:
#                       NU_ANO
# NO_MUNICIPIO_ESC
# -1                   2126423
# Abadia de Goiás           80
# Abadia dos Dourados       13
# Abadiânia                119
# Abaetetuba               699
# ...                      ...
# Áurea                      9
# Ângulo                     4
# Érico Cardoso             17
# Óbidos                   142
# Óleo                       7
#
# [5272 rows x 1 columns]

# %%
df_f[['SG_UF_ESC','NU_ANO']].groupby('SG_UF_ESC').count()
# Out:
#             NU_ANO
# SG_UF_ESC
# -1         2126423
# AC            3008
# AL           10686
# AM           33394
# AP            2863
# BA           48040
# CE           93159
# DF           16913
# ES           17657
# GO           44963
# MA           21140
# MG           64236
# MS           10672
# MT           12703
# PA           26929
# PB           17647
# PE           40227
# PI           13531
# PR           42365
# RJ           54639
# RN           12939
# RO            7699
# RR            1786
# RS           35803
# SC           26394
# SE            8480
# SP          139473
# TO            6460

# %%
df_f[['TP_LOCALIZACAO_ESC','NU_ANO']].groupby('TP_LOCALIZACAO_ESC').count()
# Out:
#                      NU_ANO
# TP_LOCALIZACAO_ESC
# -1                  2126423
# 1                    785431
# 2                     28375

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO                0
# NU_ANO                      0
# TP_FAIXA_ETARIA             0
# TP_SEXO                     0
# TP_ESTADO_CIVIL             0
# TP_COR_RACA                 0
# TP_ST_CONCLUSAO             0
# TP_ANO_CONCLUIU             0
# TP_ESCOLA                   0
# TP_ENSINO                   0
# IN_TREINEIRO                0
# CO_MUNICIPIO_ESC            0
# NO_MUNICIPIO_ESC            0
# SG_UF_ESC                   0
# TP_LOCALIZACAO_ESC          0
# CO_MUNICIPIO_PROVA          0
# NO_MUNICIPIO_PROVA          0
# SG_UF_PROVA                 0
# NU_NOTA_CN            1070918
# NU_NOTA_CH             963455
# NU_NOTA_LC             963455
# NU_NOTA_MT            1070918
# TP_LINGUA                   0
# NU_NOTA_REDACAO        963455
# Q001                        2
# Q002                        2
# Q003                        2
# Q004                        2
# Q005                        2
# Q006                        2
# Q007                        2
# Q008                        2
# Q009                        2
# Q010                        2
# Q011                        2
# Q012                        2
# Q013                        2
# Q014                        2
# Q015                        2
# Q016                        2
# Q017                        2
# Q018                        2
# Q019                        2
# Q020                        2
# Q021                        2
# Q022                        2
# Q023                        2
# Q024                        2
# Q025                        2
# dtype: int64

# %% [markdown]
# - Exclusão de informações missings no Target

# %%
df_f.dropna(subset=['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'], inplace=True, axis=0) # Axis = 0 exclui as linhas, =1, as colunas

# %%
df_f.isnull().sum()
# Out:
# NU_INSCRICAO          0
# NU_ANO                0
# TP_FAIXA_ETARIA       0
# TP_SEXO               0
# TP_ESTADO_CIVIL       0
# TP_COR_RACA           0
# TP_ST_CONCLUSAO       0
# TP_ANO_CONCLUIU       0
# TP_ESCOLA             0
# TP_ENSINO             0
# IN_TREINEIRO          0
# CO_MUNICIPIO_ESC      0
# NO_MUNICIPIO_ESC      0
# SG_UF_ESC             0
# TP_LOCALIZACAO_ESC    0
# CO_MUNICIPIO_PROVA    0
# NO_MUNICIPIO_PROVA    0
# SG_UF_PROVA           0
# NU_NOTA_CN            0
# NU_NOTA_CH            0
# NU_NOTA_LC            0
# NU_NOTA_MT            0
# TP_LINGUA             0
# NU_NOTA_REDACAO       0
# Q001                  1
# Q002                  1
# Q003                  1
# Q004                  1
# Q005                  1
# Q006                  1
# Q007                  1
# Q008                  1
# Q009                  1
# Q010                  1
# Q011                  1
# Q012                  1
# Q013                  1
# Q014                  1
# Q015                  1
# Q016                  1
# Q017                  1
# Q018                  1
# Q019                  1
# Q020                  1
# Q021                  1
# Q022                  1
# Q023                  1
# Q024                  1
# Q025                  1
# dtype: int64

# %%
df_f.shape
# Out:
# (1864224, 49)

# %% [markdown]
# - Exclusão de informações missings nas questões
# (Em sua maioria, ENEM Digital e algumas reaplicações)

# %%
df_f[df_f['Q025'].isnull()].head() # Apenas visualizar as informações missings na questão 25.
# Out:
#         NU_INSCRICAO NU_ANO TP_FAIXA_ETARIA TP_SEXO TP_ESTADO_CIVIL  \
# 707314  210052491717   2021               8       F               1
#
#        TP_COR_RACA TP_ST_CONCLUSAO TP_ANO_CONCLUIU TP_ESCOLA TP_ENSINO  ...  \
# 707314           4               1               4         1         9  ...
#
#        Q016 Q017 Q018 Q019 Q020  Q021 Q022 Q023  Q024  Q025
# 707314  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN   NaN
#
# [1 rows x 49 columns]

# %%
df_f.dropna(subset=['Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010',
                    'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020',
                    'Q021', 'Q022', 'Q023', 'Q024', 'Q025'], inplace=True, axis=0)

# %%
df_f.isnull().sum()/df_f.shape[0]*100 # % de nulos entre as questões
# Out:
# NU_INSCRICAO          0.0
# NU_ANO                0.0
# TP_FAIXA_ETARIA       0.0
# TP_SEXO               0.0
# TP_ESTADO_CIVIL       0.0
# TP_COR_RACA           0.0
# TP_ST_CONCLUSAO       0.0
# TP_ANO_CONCLUIU       0.0
# TP_ESCOLA             0.0
# TP_ENSINO             0.0
# IN_TREINEIRO          0.0
# CO_MUNICIPIO_ESC      0.0
# NO_MUNICIPIO_ESC      0.0
# SG_UF_ESC             0.0
# TP_LOCALIZACAO_ESC    0.0
# CO_MUNICIPIO_PROVA    0.0
# NO_MUNICIPIO_PROVA    0.0
# SG_UF_PROVA           0.0
# NU_NOTA_CN            0.0
# NU_NOTA_CH            0.0
# NU_NOTA_LC            0.0
# NU_NOTA_MT            0.0
# TP_LINGUA             0.0
# NU_NOTA_REDACAO       0.0
# Q001                  0.0
# Q002                  0.0
# Q003                  0.0
# Q004                  0.0
# Q005                  0.0
# Q006                  0.0
# Q007                  0.0
# Q008                  0.0
# Q009                  0.0
# Q010                  0.0
# Q011                  0.0
# Q012                  0.0
# Q013                  0.0
# Q014                  0.0
# Q015                  0.0
# Q016                  0.0
# Q017                  0.0
# Q018                  0.0
# Q019                  0.0
# Q020                  0.0
# Q021                  0.0
# Q022                  0.0
# Q023                  0.0
# Q024                  0.0
# Q025                  0.0
# dtype: float64

# %%
df_f.shape
# Out:
# (1864223, 49)

# %% [markdown]
# # **Padronização das Variáveis**

# %% [markdown]
# - Estado Civil

# %%
df_f.TP_ESTADO_CIVIL.value_counts()
# Out:
# 1    1686671
# 2      87566
# 0      63057
# 3      25099
# 4       1830
# Name: TP_ESTADO_CIVIL, dtype: int64

# %% [markdown]
# - TP_ESCOLA

# %%
df_f.TP_ESCOLA.value_counts()
# Out:
# 1    1016826
# 2     668036
# 3     179361
# Name: TP_ESCOLA, dtype: int64

# %% [markdown]
# # **Análise Descritiva**

# %% [markdown]
# - **Variáveis Quantitiativas**

# %%
round(df_f.describe(include=None),1)
# Out:
#        NU_INSCRICAO  CO_MUNICIPIO_PROVA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# count  1.864223e+06           1864223.0   1864223.0   1864223.0   1864223.0
# mean   2.100527e+11           3105121.2       493.6       524.8       504.8
# std    9.968475e+05            989736.0        81.9        95.6        79.3
# min    2.100510e+11           1100015.0         0.0         0.0         0.0
# 25%    2.100519e+11           2408102.0       431.7       449.2       448.6
# 50%    2.100527e+11           3123908.0       483.0       526.9       507.9
# 75%    2.100536e+11           3550308.0       548.2       594.6       561.7
# max    2.100545e+11           5300108.0       867.1       846.9       826.1
#
#        NU_NOTA_MT  NU_NOTA_REDACAO       Q005
# count   1864223.0        1864223.0  1864223.0
# mean        534.5            624.0        3.8
# std         112.1            183.0        1.3
# min           0.0              0.0        1.0
# 25%         443.1            520.0        3.0
# 50%         513.2            620.0        4.0
# 75%         613.6            740.0        4.0
# max         953.1           1000.0       20.0

# %% [markdown]
# - **Variáveis Qualitativas**

# %%
df_f.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU',
#        'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_LOCALIZACAO_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'NU_NOTA_CN',
#        'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015',
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object')

# %%
df_varquali = df_f[['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO',
             'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', #'NO_MUNICIPIO_ESC', 'NO_MUNICIPIO_PROVA',
             'SG_UF_ESC', 'TP_LOCALIZACAO_ESC', 'SG_UF_PROVA', 'TP_LINGUA',
             'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012',
             'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023',
             'Q024', 'Q025']]

# %%
dist_freq_quali = pd.DataFrame()
dist_freq_quali_t = list()

for column in df_varquali:
  freq_var = df_varquali[column].value_counts().sort_index()
  perc_var = df_varquali[column].value_counts(normalize=True).sort_index() * 100
  dist_freq_quali_ = pd.DataFrame({'n': freq_var,
                                   '(%)': perc_var})
  dist_freq_quali_t_ = dist_freq_quali_['n'].sum()

  dist_freq_quali = pd.concat([dist_freq_quali, dist_freq_quali_])
  dist_freq_quali_t.append(dist_freq_quali_t_)

dist_freq_quali.to_excel('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Desc_2_2021.xlsx')

# %% [markdown]
# # **Análise Gráfica (Target)**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# > **Boxplot**

# %%
labels = ['','CN','CH','LC','MT','Redação']

df_f.boxplot(column = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'],
             showmeans=True)
plt.xlabel('Competência')
plt.xticks(range(len(labels)),labels, rotation=0)
plt.ylabel('Nota')
plt.title('2021')
plt.xlim()
plt.grid()
plt.savefig('/content/drive/MyDrive/MBA_TCC/RESULTADOS/Notas_2021.png')
plt.show()

# %%
selcol = df_f[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']]

# %%
sns.set_theme(style="ticks")
sns.pairplot(selcol)

# %% [markdown]
# # **Análise de Correlação**

# %% [markdown]
# - Entre as variáveis respostas

# %%
corr1 = selcol.corr(method='pearson')
print(corr1)
corr2 = selcol.corr(method='spearman')
print(corr2)

plt.imshow(corr2, cmap='hot', interpolation='none')
plt.colorbar()
plt.title('2021')
plt.xticks(range(len(corr2)), rotation=90, labels=['CN','CH','LC','MT','Redação'])
plt.yticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação']);
plt.show()
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_NOTA_CN         1.000000    0.684148    0.670837    0.682110
# NU_NOTA_CH         0.684148    1.000000    0.758207    0.634619
# NU_NOTA_LC         0.670837    0.758207    1.000000    0.635720
# NU_NOTA_MT         0.682110    0.634619    0.635720    1.000000
# NU_NOTA_REDACAO    0.483613    0.494363    0.518697    0.502785
#
#                  NU_NOTA_REDACAO
# NU_NOTA_CN              0.483613
# NU_NOTA_CH              0.494363
# NU_NOTA_LC              0.518697
# NU_NOTA_MT              0.502785
# NU_NOTA_REDACAO         1.000000
#                  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# NU_NOTA_CN         1.000000    0.669316    0.666725    0.608387
# NU_NOTA_CH         0.669316    1.000000    0.766545    0.607989
# NU_NOTA_LC         0.666725    0.766545    1.000000    0.622667
# NU_NOTA_MT         0.608387    0.607989    0.622667    1.000000
# NU_NOTA_REDACAO    0.489614    0.518260    0.543716    0.513371
#
#                  NU_NOTA_REDACAO
# NU_NOTA_CN              0.489614
# NU_NOTA_CH              0.518260
# NU_NOTA_LC              0.543716
# NU_NOTA_MT              0.513371
# NU_NOTA_REDACAO         1.000000

# %%
plt.figure(figsize=(15,8))
matriz = np.triu(corr2)
sns.heatmap(corr2, mask= matriz, annot=True, cmap='YlGnBu')
plt.title('2021')
plt.xticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação'])
plt.yticks(range(len(corr2)), rotation=0, labels=['CN','CH','LC','MT','Redação']);
plt.savefig("/content/drive/MyDrive/MBA_TCC/RESULTADOS/Notas_2021 - Matriz de Correlacao (S).png")
plt.show()

# %% [markdown]
# # **Validações**

# %%
tb4 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ENSINO, margins=True, dropna=False)
display(tb4)
# Out:
# TP_ENSINO       1     2        9      All
# SG_UF_ESC
# -1         234928  1879  1024965  1261772
# AC           2196     9       46     2251
# AL           8438    67      182     8687
# AM          15193    94      554    15841
# AP           2084    11       57     2152
# BA          33683   256      943    34882
# CE          57634   180      689    58503
# DF          14180    34      260    14474
# ES          13522    40      359    13921
# GO          23885   127      494    24506
# MA          16145    74      269    16488
# MG          49540   138      850    50528
# MS           7931    27      123     8081
# MT           9389    38      126     9553
# PA          20495    79      531    21105
# PB          13090    70      322    13482
# PE          29324   110      529    29963
# PI          10960    46      263    11269
# PR          32637   132      269    33038
# RJ          43186   181      959    44326
# RN          10662    41      316    11019
# RO           4744    19      179     4942
# RR           1217     0       17     1234
# RS          27522    86      453    28061
# SC          19662    43      174    19879
# SE           6648    26       90     6764
# SP         111610   297     1101   113008
# TO           4366    21      107     4494
# All        824871  4125  1035227  1864223

# %%
tb5 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ANO_CONCLUIU, margins=True, dropna=False)
display(tb5)
# Out:
# TP_ANO_CONCLUIU       0       1     10     11     12     13     14     15  \
# SG_UF_ESC
# -1               326747  276836  16987  15343  13831  11864  11037  93846
# AC                 2251       0      0      0      0      0      0      0
# AL                 8687       0      0      0      0      0      0      0
# AM                15841       0      0      0      0      0      0      0
# AP                 2152       0      0      0      0      0      0      0
# BA                34882       0      0      0      0      0      0      0
# CE                58503       0      0      0      0      0      0      0
# DF                14474       0      0      0      0      0      0      0
# ES                13921       0      0      0      0      0      0      0
# GO                24506       0      0      0      0      0      0      0
# MA                16488       0      0      0      0      0      0      0
# MG                50528       0      0      0      0      0      0      0
# MS                 8081       0      0      0      0      0      0      0
# MT                 9553       0      0      0      0      0      0      0
# PA                21105       0      0      0      0      0      0      0
# PB                13482       0      0      0      0      0      0      0
# PE                29963       0      0      0      0      0      0      0
# PI                11269       0      0      0      0      0      0      0
# PR                33038       0      0      0      0      0      0      0
# RJ                44326       0      0      0      0      0      0      0
# RN                11019       0      0      0      0      0      0      0
# RO                 4942       0      0      0      0      0      0      0
# RR                 1234       0      0      0      0      0      0      0
# RS                28061       0      0      0      0      0      0      0
# SC                19879       0      0      0      0      0      0      0
# SE                 6764       0      0      0      0      0      0      0
# SP               113008       0      0      0      0      0      0      0
# TO                 4494       0      0      0      0      0      0      0
# All              929198  276836  16987  15343  13831  11864  11037  93846
#
# TP_ANO_CONCLUIU       2       3      4      5      6      7      8      9  \
# SG_UF_ESC
# -1               158387  100071  70781  50492  38899  30956  24727  20968
# AC                    0       0      0      0      0      0      0      0
# AL                    0       0      0      0      0      0      0      0
# AM                    0       0      0      0      0      0      0      0
# AP                    0       0      0      0      0      0      0      0
# BA                    0       0      0      0      0      0      0      0
# CE                    0       0      0      0      0      0      0      0
# DF                    0       0      0      0      0      0      0      0
# ES                    0       0      0      0      0      0      0      0
# GO                    0       0      0      0      0      0      0      0
# MA                    0       0      0      0      0      0      0      0
# MG                    0       0      0      0      0      0      0      0
# MS                    0       0      0      0      0      0      0      0
# MT                    0       0      0      0      0      0      0      0
# PA                    0       0      0      0      0      0      0      0
# PB                    0       0      0      0      0      0      0      0
# PE                    0       0      0      0      0      0      0      0
# PI                    0       0      0      0      0      0      0      0
# PR                    0       0      0      0      0      0      0      0
# RJ                    0       0      0      0      0      0      0      0
# RN                    0       0      0      0      0      0      0      0
# RO                    0       0      0      0      0      0      0      0
# RR                    0       0      0      0      0      0      0      0
# RS                    0       0      0      0      0      0      0      0
# SC                    0       0      0      0      0      0      0      0
# SE                    0       0      0      0      0      0      0      0
# SP                    0       0      0      0      0      0      0      0
# TO                    0       0      0      0      0      0      0      0
# All              158387  100071  70781  50492  38899  30956  24727  20968
#
# TP_ANO_CONCLUIU      All
# SG_UF_ESC
# -1               1261772
# AC                  2251
# AL                  8687
# AM                 15841
# AP                  2152
# BA                 34882
# CE                 58503
# DF                 14474
# ES                 13921
# GO                 24506
# MA                 16488
# MG                 50528
# MS                  8081
# MT                  9553
# PA                 21105
# PB                 13482
# PE                 29963
# PI                 11269
# PR                 33038
# RJ                 44326
# RN                 11019
# RO                  4942
# RR                  1234
# RS                 28061
# SC                 19879
# SE                  6764
# SP                113008
# TO                  4494
# All              1864223

# %%
tb6 = pd.crosstab(df_f.SG_UF_ESC,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb6)
# Out:
# TP_ST_CONCLUSAO        1       2  3  4      All
# SG_UF_ESC
# -1               1016824  244948  0  0  1261772
# AC                     0    2251  0  0     2251
# AL                     0    8687  0  0     8687
# AM                     0   15841  0  0    15841
# AP                     0    2152  0  0     2152
# BA                     0   34882  0  0    34882
# CE                     0   58503  0  0    58503
# DF                     0   14474  0  0    14474
# ES                     0   13921  0  0    13921
# GO                     0   24506  0  0    24506
# MA                     0   16488  0  0    16488
# MG                     0   50528  0  0    50528
# MS                     0    8081  0  0     8081
# MT                     0    9553  0  0     9553
# PA                     0   21105  0  0    21105
# PB                     0   13482  0  0    13482
# PE                     0   29963  0  0    29963
# PI                     0   11269  0  0    11269
# PR                     0   33038  0  0    33038
# RJ                     0   44326  0  0    44326
# RN                     0   11019  0  0    11019
# RO                     0    4942  0  0     4942
# RR                     0    1234  0  0     1234
# RS                     0   28061  0  0    28061
# SC                     0   19879  0  0    19879
# SE                     0    6764  0  0     6764
# SP                     0  113008  0  0   113008
# TO                     0    4494  0  0     4494
# All              1016824  847399  0  0  1864223

# %%
tb7 = pd.crosstab(df_f.TP_ESCOLA,df_f.TP_ST_CONCLUSAO, margins=True, dropna=False)
display(tb7)
# Out:
# TP_ST_CONCLUSAO        1       2  3  4      All
# TP_ESCOLA
# 1                1016824       2  0  0  1016826
# 2                      0  668036  0  0   668036
# 3                      0  179361  0  0   179361
# All              1016824  847399  0  0  1864223

# %% [markdown]
# # **Exclusão de Colunas**

# %%
df_f.drop(['IN_TREINEIRO'], axis = 1, inplace = True)
df_f.shape
# Out:
# (1864223, 48)

# %% [markdown]
# # **Verificação de Duplicidade na Base Final**

# %%
df_f.NU_INSCRICAO.unique()
# Out:
# array([210052384164, 210052128335, 210051353021, ..., 210051121001,
#        210051173067, 210051139675])

# %%
df_f.shape
# Out:
# (1864223, 48)

# %% [markdown]
# # **Exportar base final**

# %%
df_f.to_csv('/content/drive/MyDrive/MBA_TCC/DADOS/df_f_2021.csv', index=False)

# %%
#selcol.to_csv('/content/drive/MyDrive/MBA_TCC/DADOS/notas_2018.csv', index=False)

# %% [markdown]
# # **Separação Input/Target**

# %%
y = dadosv['style']
x = dadosv.drop('style', axis = 1)

# %% [markdown]
# # **Train/Test**

# %%
# BIBLIOTECA SCIKIT LEARN

from sklearn.model_selection import train_test_split


# Dados de Treino/Teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.3)
print(x_treino.shape)
print(x_teste.shape)
print(y_treino.shape)
print(y_teste.shape)
